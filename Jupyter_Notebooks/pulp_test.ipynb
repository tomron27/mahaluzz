# %% [markdown]
# # Introduction to Linear Programming with Python - Part 5
# ## Using PuLP with pandas and binary constraints to solve a scheduling problem

# %% [markdown]
# In this example, we'll be solving a scheduling problem. We have 2 offshore production plants in 2 locations and an estimated demand for our products.
#
# We want to produce a schedule of production from both plants that meets our demand with the lowest cost.
#
# A factory can be in 2 states:
# * Off - Producing zero units
# * On - Producing between its minimum and maximum production capacities
#
# Both factories have fixed costs, that are incurred as long as the factory is on, and variable costs, a cost per unit of production. These vary month by month.
#
# We also know that factory B is down for maintenance in month 5.
#
# We'll start by importing our data.
#
# The data is imported into a multi-index pandas DataFrame using 'Month' and 'Factory' as our index columns.

# %%
import pandas as pd
import numpy as np
import itertools
import pulp

# %%
# Init
DAYS = [1,2,3,4,5,6]
HOURS = [1,2,3,4,5,6]
LESSONS = ['Math', 'Science', 'Bible']
CLASSES = ['A1', 'A2', 'A3']
TEACHERS = ['Ruti', 'Shoshi', 'Miriam']

lessons_columns = ['Day', 'Hour', 'Lesson', 'Class', 'Teacher']
lessons_data = pd.DataFrame(columns=lessons_columns)
lessons_cart_input = (DAYS, HOURS, LESSONS, CLASSES, TEACHERS)

teachers_const_columns = ['Teacher', 'Day', 'Hour', 'Value']
teachers_data = pd.DataFrame(columns=teachers_const_columns)
teachers_cart_input = (TEACHERS, DAYS, HOURS, [1])

edu_const_columns = ['Class', 'Lesson', 'Value']
edu_data = pd.DataFrame(columns=edu_const_columns)
edu_cart_input = (CLASSES, LESSONS, [8])

lessons_cart = itertools.product(*lessons_cart_input, repeat=1)
teachers_cart = itertools.product(*teachers_cart_input, repeat=1)
edu_cart = itertools.product(*edu_cart_input, repeat=1)

print('expected num of variables: {}'.format(len(DAYS)*len(HOURS)*len(LESSONS)*len(CLASSES)*len(TEACHERS)))
# Out:
# expected num of variables: 972

# %%
for i, out in enumerate(lessons_cart):
    lessons_data.loc[i] = out
print(lessons_data.shape)

for i, out in enumerate(teachers_cart):
    teachers_data.loc[i] = out
teachers_data = teachers_data.drop_duplicates()
print(teachers_data.shape)

for i, out in enumerate(edu_cart):
    edu_data.loc[i] = out
edu_data = edu_data.drop_duplicates()
print(edu_data.shape)

dummy_data =  {'Teacher': ['Ruti', 'Ruti', 'Ruti', 'Shoshi', 'Shoshi', 'Shoshi', 'Miriam', 'Miriam', 'Miriam'],
               'Lesson': ['Math', 'Science', 'Bible', 'Math', 'Science', 'Bible', 'Math', 'Science', 'Bible'],
               'Value': [1, 1, 1, 1, 0, 1, 0, 0, 1]}
# print(dummy_data)
teachers_lesson_data = pd.DataFrame(data=dummy_data)
print(teachers_lesson_data.shape)
# Out:
# (972, 5)
# (108, 4)
# (9, 3)
# (9, 3)

# %%
lessons_data.head(10)
# Out:
#   Day Hour   Lesson Class Teacher
# 0   1    1     Math    A1    Ruti
# 1   1    1     Math    A1  Shoshi
# 2   1    1     Math    A1  Miriam
# 3   1    1     Math    A2    Ruti
# 4   1    1     Math    A2  Shoshi
# 5   1    1     Math    A2  Miriam
# 6   1    1     Math    A3    Ruti
# 7   1    1     Math    A3  Shoshi
# 8   1    1     Math    A3  Miriam
# 9   1    1  Science    A1    Ruti

# %%
teachers_data.head(10)
# Out:
#   Teacher Day Hour Value
# 0    Ruti   1    1     1
# 1    Ruti   1    2     1
# 2    Ruti   1    3     1
# 3    Ruti   1    4     1
# 4    Ruti   1    5     1
# 5    Ruti   1    6     1
# 6    Ruti   2    1     1
# 7    Ruti   2    2     1
# 8    Ruti   2    3     1
# 9    Ruti   2    4     1

# %%
edu_data.head(10)
# Out:
#   Class   Lesson Value
# 0    A1     Math     8
# 1    A1  Science     8
# 2    A1    Bible     8
# 3    A2     Math     8
# 4    A2  Science     8
# 5    A2    Bible     8
# 6    A3     Math     8
# 7    A3  Science     8
# 8    A3    Bible     8

# %%
teachers_lesson_data.head(10)
# Out:
#   Teacher   Lesson  Value
# 0    Ruti     Math      1
# 1    Ruti  Science      1
# 2    Ruti    Bible      1
# 3  Shoshi     Math      1
# 4  Shoshi  Science      0
# 5  Shoshi    Bible      1
# 6  Miriam     Math      0
# 7  Miriam  Science      0
# 8  Miriam    Bible      1

# %%
lessons_dict = pulp.LpVariable.dicts("variables",
                                     ((row.Day, row.Hour, row.Lesson, row.Class, row.Teacher) for row in lessons_data.itertuples()),
                                     lowBound=0,
                                     cat='Binary')

# %% [markdown]
# We instantiate our model and use LpMinimize as the aim is to minimise costs.

# %% [markdown]
# ## Model initialization

# %%
all_data = lessons_data.merge(teachers_data, on=['Teacher', 'Day', 'Hour'])

# %%
model = pulp.LpProblem("Minimize amount of lessons", pulp.LpMinimize)

# %%
# Objective function build
expr = []
for row in all_data.itertuples():
    expr += lessons_dict[row.Day, row.Hour, row.Lesson, row.Class, row.Teacher] * row.Value
model += expr

# %% [markdown]
# ### Constraints

# %%
# How many hours for every class for every lesson
for edu_row in edu_data.itertuples():
    lp_sum = []
    expr = pulp.LpAffineExpression()
    for lesson_row in lessons_data[(lessons_data['Lesson'] == edu_row.Lesson) & (lessons_data['Class'] == edu_row.Class)].drop_duplicates().itertuples():
        lp_sum += lessons_dict[lesson_row.Day, lesson_row.Hour, lesson_row.Lesson, lesson_row.Class, lesson_row.Teacher]
    expr = (lp_sum == edu_row.Value)
    model += expr

# %%
# Teachers can teach only one class per hour
for row in lessons_data[['Teacher', 'Day', 'Hour']].drop_duplicates().itertuples():
    lp_sum = []
    expr = pulp.LpAffineExpression()
    for lesson_row in lessons_data[(lessons_data['Teacher'] == row.Teacher) & (lessons_data['Day'] == row.Day) & (lessons_data['Hour'] == row.Hour)].drop_duplicates().itertuples():
        lp_sum += lessons_dict[lesson_row.Day, lesson_row.Hour, lesson_row.Lesson, lesson_row.Class, lesson_row.Teacher]
    expr = (lp_sum <= 1)
#     print(expr, '\n\n')
    model += expr

# %%
# Classes can have only one lesson per hour
for row in lessons_data[['Class', 'Day', 'Hour']].drop_duplicates().itertuples():
    lp_sum = []
    expr = pulp.LpAffineExpression()
    for lesson_row in lessons_data[(lessons_data['Class'] == row.Class) & (lessons_data['Day'] == row.Day) & (lessons_data['Hour'] == row.Hour)].drop_duplicates().itertuples():
        lp_sum += lessons_dict[lesson_row.Day, lesson_row.Hour, lesson_row.Lesson, lesson_row.Class, lesson_row.Teacher]
    expr = (lp_sum <= 1)
#     print(expr, '\n\n')
    model += expr

# %%
# Window variables
L_dict = pulp.LpVariable.dicts("variables",
                                     ((row.Day, row.Hour, row.Class, 'L') for row in lessons_data[['Day', 'Hour', 'Class']].drop_duplicates().itertuples()),
                                     lowBound=0,
                                     cat='Binary')

Y_dict = pulp.LpVariable.dicts("variables",
                                     ((row.Day, row.Hour, row.Class, 'Y') for row in lessons_data[['Day', 'Hour', 'Class']].drop_duplicates().itertuples()),
                                     lowBound=0,
                                     cat='Binary')

Z_dict = pulp.LpVariable.dicts("variables",
                                     ((row.Day, row.Hour, row.Class, 'Z') for row in lessons_data[['Day', 'Hour', 'Class']].drop_duplicates().itertuples()),
                                     lowBound=0,
                                     cat='Binary')

# %%
# Window constraints
for row, L_ijl in L_dict.items():
    expr = pulp.LpAffineExpression()
    sub_expr = pulp.LpAffineExpression()
    lp_sum = []
    for sub_row in lessons_data[(lessons_data['Day'] == row[0]) & (lessons_data['Hour'] == row[1]) & (lessons_data['Class'] == row[2])].drop_duplicates().itertuples():
        lp_sum += lessons_dict[sub_row.Day, sub_row.Hour, sub_row.Lesson, sub_row.Class, sub_row.Teacher]
    expr = (L_ijl - lp_sum == 0)
#     print(expr)
    model += expr

for row, L_ijl in L_dict.items():
    if row[1] <= max(HOURS)-1:
        expr = pulp.LpAffineExpression()
        expr = (L_dict[row] - L_dict[(row[0], row[1]+1, row[2], 'L')] + Y_dict[(row[0], row[1]+1, row[2], 'Y')] - Z_dict[(row[0], row[1]+1, row[2], 'Z')] == 0)
        model += expr

for row in lessons_data[['Class', 'Day', 'Hour']].drop_duplicates().itertuples():
    lp_sum = []
    expr = pulp.LpAffineExpression()
    for lesson_row in lessons_data[['Class', 'Day', 'Hour']][(lessons_data['Class'] == row.Class) & (lessons_data['Day'] == row.Day)].drop_duplicates().itertuples():
        lp_sum += Y_dict[lesson_row.Day, lesson_row.Hour, lesson_row.Class, 'Y']
    expr = (lp_sum <= 1)
#     print(expr, '\n\n')
    model += expr  

for row in lessons_data[['Class', 'Day', 'Hour']].drop_duplicates().itertuples():
    lp_sum = []
    expr = pulp.LpAffineExpression()
    for lesson_row in lessons_data[['Class', 'Day', 'Hour']][(lessons_data['Class'] == row.Class) & (lessons_data['Day'] == row.Day)].drop_duplicates().itertuples():
        lp_sum += Z_dict[lesson_row.Day, lesson_row.Hour, lesson_row.Class, 'Z']
    expr = (lp_sum <= 1)
#     print(expr, '\n\n')
    model += expr

# %%
# Teacher lessons constraints
for row in lessons_data.drop_duplicates().itertuples():
    expr = pulp.LpAffineExpression()
    expr = (lessons_dict[row.Day, row.Hour, row.Lesson, row.Class, row.Teacher] <= teachers_lesson_data[(teachers_lesson_data['Teacher'] == row.Teacher) & (teachers_lesson_data['Lesson'] == row.Lesson)]['Value'])
#     print(expr, '\n\n')
    model += expr

# %%
print(model)
# Out:
# Minimize amount of lessons:
# MINIMIZE
# 1*variables_(1,_1,_'Bible',_'A1',_'Miriam') + 1*variables_(1,_1,_'Bible',_'A1',_'Ruti') + 1*variables_(1,_1,_'Bible',_'A1',_'Shoshi') + 1*variables_(1,_1,_'Bible',_'A2',_'Miriam') + 1*variables_(1,_1,_'Bible',_'A2',_'Ruti') + 1*variables_(1,_1,_'Bible',_'A2',_'Shoshi') + 1*variables_(1,_1,_'Bible',_'A3',_'Miriam') + 1*variables_(1,_1,_'Bible',_'A3',_'Ruti') + 1*variables_(1,_1,_'Bible',_'A3',_'Shoshi') + 1*variables_(1,_1,_'Math',_'A1',_'Miriam') + 1*variables_(1,_1,_'Math',_'A1',_'Ruti') + 1*variables_(1,_1,_'Math',_'A1',_'Shoshi') + 1*variables_(1,_1,_'Math',_'A2',_'Miriam') + 1*variables_(1,_1,_'Math',_'A2',_'Ruti') + 1*variables_(1,_1,_'Math',_'A2',_'Shoshi') + 1*variables_(1,_1,_'Math',_'A3',_'Miriam') + 1*variables_(1,_1,_'Math',_'A3',_'Ruti') + 1*variables_(1,_1,_'Math',_'A3',_'Shoshi') + 1*variables_(1,_1,_'Science',_'A1',_'Miriam') + 1*variables_(1,_1,_'Science',_'A1',_'Ruti') + 1*variables_(1,_1,_'Science',_'A1',_'Shoshi') + 1*variables_(1,_1,_'Science',_'A2',_'Miriam') + 1*variables_(1,_1,_'Science',_'A2',_'Ruti') + 1*variables_(1,_1,_'Science',_'A2',_'Shoshi') + 1*variables_(1,_1,_'Science',_'A3',_'Miriam') + 1*variables_(1,_1,_'Science',_'A3',_'Ruti') + 1*variables_(1,_1,_'Science',_'A3',_'Shoshi') + 1*variables_(1,_2,_'Bible',_'A1',_'Miriam') + 1*variables_(1,_2,_'Bible',_'A1',_'Ruti') + 1*variables_(1,_2,_'Bible',_'A1',_'Shoshi') + 1*variables_(1,_2,_'Bible',_'A2',_'Miriam') + 1*variables_(1,_2,_'Bible',_'A2',_'Ruti') + 1*variables_(1,_2,_'Bible',_'A2',_'Shoshi') + 1*variables_(1,_2,_'Bible',_'A3',_'Miriam') + 1*variables_(1,_2,_'Bible',_'A3',_'Ruti') + 1*variables_(1,_2,_'Bible',_'A3',_'Shoshi') + 1*variables_(1,_2,_'Math',_'A1',_'Miriam') + 1*variables_(1,_2,_'Math',_'A1',_'Ruti') + 1*variables_(1,_2,_'Math',_'A1',_'Shoshi') + 1*variables_(1,_2,_'Math',_'A2',_'Miriam') + 1*variables_(1,_2,_'Math',_'A2',_'Ruti') + 1*variables_(1,_2,_'Math',_'A2',_'Shoshi') + 1*variables_(1,_2,_'Math',_'A3',_'Miriam') + 1*variables_(1,_2,_'Math',_'A3',_'Ruti') + 1*variables_(1,_2,_'Math',_'A3',_'Shoshi') + 1*variables_(1,_2,_'Science',_'A1',_'Miriam') + 1*variables_(1,_2,_'Science',_'A1',_'Ruti') + 1*variables_(1,_2,_'Science',_'A1',_'Shoshi') + 1*variables_(1,_2,_'Science',_'A2',_'Miriam') + 1*variables_(1,_2,_'Science',_'A2',_'Ruti') + 1*variables_(1,_2,_'Science',_'A2',_'Shoshi') + 1*variables_(1,_2,_'Science',_'A3',_'Miriam') + 1*variables_(1,_2,_'Science',_'A3',_'Ruti') + 1*variables_(1,_2,_'Science',_'A3',_'Shoshi') + 1*variables_(1,_3,_'Bible',_'A1',_'Miriam') + 1*variables_(1,_3,_'Bible',_'A1',_'Ruti') + 1*variables_(1,_3,_'Bible',_'A1',_'Shoshi') + 1*variables_(1,_3,_'Bible',_'A2',_'Miriam') + 1*variables_(1,_3,_'Bible',_'A2',_'Ruti') + 1*variables_(1,_3,_'Bible',_'A2',_'Shoshi') + 1*variables_(1,_3,_'Bible',_'A3',_'Miriam') + 1*variables_(1,_3,_'Bible',_'A3',_'Ruti') + 1*variables_(1,_3,_'Bible',_'A3',_'Shoshi') + 1*variables_(1,_3,_'Math',_'A1',_'Miriam') + 1*variables_(1,_3,_'Math',_'A1',_'Ruti') + 1*variables_(1,_3,_'Math',_'A1',_'Shoshi') + 1*variables_(1,_3,_'Math',_'A2',_'Miriam') + 1*variables_(1,_3,_'Math',_'A2',_'Ruti') + 1*variables_(1,_3,_'Math',_'A2',_'Shoshi') + 1*variables_(1,_3,_'Math',_'A3',_'Miriam') + 1*variables_(1,_3,_'Math',_'A3',_'Ruti') + 1*variables_(1,_3,_'Math',_'A3',_'Shoshi') + 1*variables_(1,_3,_'Science',_'A1',_'Miriam') + 1*variables_(1,_3,_'Science',_'A1',_'Ruti') + 1*variables_(1,_3,_'Science',_'A1',_'Shoshi') + 1*variables_(1,_3,_'Science',_'A2',_'Miriam') + 1*variables_(1,_3,_'Science',_'A2',_'Ruti') + 1*variables_(1,_3,_'Science',_'A2',_'Shoshi') + 1*variables_(1,_3,_'Science',_'A3',_'Miriam') + 1*variables_(1,_3,_'Science',_'A3',_'Ruti') + 1*variables_(1,_3,_'Science',_'A3',_'Shoshi') + 1*variables_(1,_4,_'Bible',_'A1',_'Miriam') + 1*variables_(1,_4,_'Bible',_'A1',_'Ruti') + 1*variables_(1,_4,_'Bible',_'A1',_'Shoshi') + 1*variables_(1,_4,_'Bible',_'A2',_'Miriam') + 1*variables_(1,_4,_'Bible',_'A2',_'Ruti') + 1*variables_(1,_4,_'Bible',_'A2',_'Shoshi') + 1*variables_(1,_4,_'Bible',_' ...
# SUBJECT TO
# _C1: variables_(1,_1,_'Math',_'A1',_'Miriam')
#  + variables_(1,_1,_'Math',_'A1',_'Ruti')
#  + variables_(1,_1,_'Math',_'A1',_'Shoshi')
#  + variables_(1,_2,_'Math',_'A1',_'Miriam')
#  + variables_(1,_2,_'Math',_'A1',_'Ruti')
#  + variables_(1,_2,_'Math',_'A1',_'Shoshi')
#  + variables_(1,_3,_'Math',_'A1',_'Miriam')
#  + variables_(1,_3,_'Math',_'A1',_'Ruti')
#  + variables_(1,_3,_'Math',_'A1',_'Shoshi')
#  + variables_(1,_4,_'Math',_'A1',_'Miriam')
#  + variables_(1,_4,_'Math',_'A1',_'Ruti')
#  + variables_(1,_4,_'Math',_'A1',_'Shoshi')
#  + variables_(1,_5,_'Math',_'A1',_'Miriam')
#  + variables_(1,_5,_'Math',_'A1',_'Ruti')
#  + variables_(1,_5,_'Math',_'A1',_'Shoshi')
#  + variables_(1,_6,_'Math',_'A1',_'Miriam')
#  + variables_(1,_6,_'Math',_'A1',_'Ruti')
#  + variables_(1,_6,_'Math',_'A1',_'Shoshi')
#  + variables_(2,_1,_'Math',_'A1',_'Miriam')
#  + variables_(2,_1,_'Math',_'A1',_'Ruti')
#  + variables_(2,_1,_'Math',_'A1',_'Shoshi')
#  + variables_(2,_2,_'Math',_'A1',_'Miriam')
#  + variables_(2,_2,_'Math',_'A1',_'Ruti')
#  + variables_(2,_2,_'Math',_'A1',_'Shoshi')
#  + variables_(2,_3,_'Math',_'A1',_'Miriam')
#  + variables_(2,_3,_'Math',_'A1',_'Ruti')
#  + variables_(2,_3,_'Math',_'A1',_'Shoshi')
#  + variables_(2,_4,_'Math',_'A1',_'Miriam')
#  + variables_(2,_4,_'Math',_'A1',_'Ruti')
#  + variables_(2,_4,_'Math',_'A1',_'Shoshi')
#  + variables_(2,_5,_'Math',_'A1',_'Miriam')
#  + variables_(2,_5,_'Math',_'A1',_'Ruti')
#  + variables_(2,_5,_'Math',_'A1',_'Shoshi')
#  + variables_(2,_6,_'Math',_'A1',_'Miriam')
#  + variables_(2,_6,_'Math',_'A1',_'Ruti')
#  + variables_(2,_6,_'Math',_'A1',_'Shoshi')
#  + variables_(3,_1,_'Math',_'A1',_'Miriam')
#  + variables_(3,_1,_'Math',_'A1',_'Ruti')
#  + variables_(3,_1,_'Math',_'A1',_'Shoshi')
#  + variables_(3,_2,_'Math',_'A1',_'Miriam')
#  + variables_(3,_2,_'Math',_'A1',_'Ruti')
#  + variables_(3,_2,_'Math',_'A1',_'Shoshi')
#  + variables_(3,_3,_'Math',_'A1',_'Miriam')
#  + variables_(3,_3,_'Math',_'A1',_'Ruti')
#  + variables_(3,_3,_'Math',_'A1',_'Shoshi')
#  + variables_(3,_4,_'Math',_'A1',_'Miriam')
#  + variables_(3,_4,_'Math',_'A1',_'Ruti')
#  + variables_(3,_4,_'Math',_'A1',_'Shoshi')
#  + variables_(3,_5,_'Math',_'A1',_'Miriam')
#  + variables_(3,_5,_'Math',_'A1',_'Ruti')
#  + variables_(3,_5,_'Math',_'A1',_'Shoshi')
#  + variables_(3,_6,_'Math',_'A1',_'Miriam')
#  + variables_(3,_6,_'Math',_'A1',_'Ruti')
#  + variables_(3,_6,_'Math',_'A1',_'Shoshi')
#  + variables_(4,_1,_'Math',_'A1',_'Miriam')
#  + variables_(4,_1,_'Math',_'A1',_'Ruti')
#  + variables_(4,_1,_'Math',_'A1',_'Shoshi')
#  + variables_(4,_2,_'Math',_'A1',_'Miriam')
#  + variables_(4,_2,_'Math',_'A1',_'Ruti')
#  + variables_(4,_2,_'Math',_'A1',_'Shoshi')
#  + variables_(4,_3,_'Math',_'A1',_'Miriam')
#  + variables_(4,_3,_'Math',_'A1',_'Ruti')
#  + variables_(4,_3,_'Math',_'A1',_'Shoshi')
#  + variables_(4,_4,_'Math',_'A1',_'Miriam')
#  + variables_(4,_4,_'Math',_'A1',_'Ruti')
#  + variables_(4,_4,_'Math',_'A1',_'Shoshi')
#  + variables_(4,_5,_'Math',_'A1',_'Miriam')
#  + variables_(4,_5,_'Math',_'A1',_'Ruti')
#  + variables_(4,_5,_'Math',_'A1',_'Shoshi')
#  + variables_(4,_6,_'Math',_'A1',_'Miriam')
#  + variables_(4,_6,_'Math',_'A1',_'Ruti')
#  + variables_(4,_6,_'Math',_'A1',_'Shoshi')
#  + variables_(5,_1,_'Math',_'A1',_'Miriam')
#  + variables_(5,_1,_'Math',_'A1',_'Ruti')
#  + variables_(5,_1,_'Math',_'A1',_'Shoshi')
#  + variables_(5,_2,_'Math',_'A1',_'Miriam')
#  + variables_(5,_2,_'Math',_'A1',_'Ruti')
#  + variables_(5,_2,_'Math',_'A1',_'Shoshi')
#  + variables_(5,_3,_'Math',_'A1',_'Miriam')
#  + variables_(5,_3,_'Math',_'A1',_'Ruti')
#  + variables_(5,_3,_'Math',_'A1',_'Shoshi')
#  + variables_(5,_4,_'Math',_'A1',_'Miriam')
#  + variables_(5,_4,_'Math',_'A1',_'Ruti')
#  + variables_(5,_4,_'Math',_'A1',_'Shoshi')
#  + variables_(5,_5,_'Math',_'A1',_'Miriam')
#  + variables_(5,_5,_'Math',_'A1',_'Ruti')
#  + variables_(5,_5,_'Math',_'A1',_'Shoshi')
#  + variables_(5,_6,_'Math',_'A1',_'Miriam')
#  + variables_(5,_6,_'Math',_'A1',_'Ruti')
#  + variables_(5,_6,_'Math',_'A1',_'Shoshi')
#  + variables_(6,_1,_'Math',_'A1',_'Miriam')
#  + variables_(6,_1,_'Math',_'A1',_'Ruti')
#  + variables_(6,_1,_'Math',_'A1',_'Shoshi')
#  + variables_(6,_2,_'Math',_'A1',_'Miriam')
#  + variables_(6,_2,_'Math',_'A1',_'Ruti')
#  + variables_(6,_2,_'Math',_'A1',_'Shoshi')
#  + variables_(6,_3,_'Math',_'A1',_'Miriam')
#  + variables_(6,_3,_'Math',_'A1',_'Ruti')
#  + variables_(6,_3,_'Math',_'A1',_'Shoshi')
#  + variables_(6,_4,_'Math',_'A1',_'Miriam')
#  + variables_(6,_4,_'Math',_'A1',_'Ruti')
#  + variables_(6,_4,_'Math',_'A1',_'Shoshi')
#  + variables_(6,_5,_'Math',_'A1',_'Miriam')
#  + variables_(6,_5,_'Math',_'A1',_'Ruti')
#  + variables_(6,_5,_'Math',_'A1',_'Shoshi')
#  + variables_(6,_6,_'Math',_'A1',_'Miriam')
#  + variables_(6,_6,_'Math',_'A1',_'Ruti')
#  + variables_(6,_6,_'Math',_'A1',_'Shoshi') = 8
#
# _C2: variables_(1,_1,_'Science',_'A1',_'Miriam')
#  + variables_(1,_1,_'Science',_'A1',_'Ruti')
#  + variables_(1,_1,_'Science',_'A1',_'Shoshi')
#  + variables_(1,_2,_'Science',_'A1',_'Miriam')
#  + variables_(1,_2,_'Science',_'A1',_'Ruti')
#  + variables_(1,_2,_'Science',_'A1',_'Shoshi')
#  + variables_(1,_3,_'Science',_'A1',_'Miriam')
#  + variables_(1,_3,_'Science',_'A1',_'Ruti')
#  + variables_(1,_3,_'Science',_'A1',_'Shoshi')
#  + variables_(1,_4,_'Science',_'A1',_'Miriam')
#  + variables_(1,_4,_'Science',_'A1',_'Ruti')
#  + variables_(1,_4,_'Science',_'A1',_'Shoshi')
#  + variables_(1,_5,_'Science',_'A1',_'Miriam')
#  + variables_(1,_5,_'Science',_'A1',_'Ruti')
#  + variables_(1,_5,_'Science',_'A1',_'Shoshi')
#  + variables_(1,_6,_'Science',_'A1',_'Miriam')
#  + variables_(1,_6,_'Science',_'A1',_'Ruti')
#  + variables_(1,_6,_'Science',_'A1',_'Shoshi')
#  + variables_(2,_1,_'Science',_'A1',_'Miriam')
#  + variables_(2,_1,_'Science',_'A1',_'Ruti')
#  + variables_(2,_1,_'Science',_'A1',_'Shoshi')
#  + variables_(2,_2,_'Science',_'A1',_'Miriam')
#  + variables_(2,_2,_'Science',_'A1',_'Ruti')
#  + variables_(2,_2,_'Science',_'A1',_'Shoshi')
#  + variables_(2,_3,_'Science',_'A1',_'Miriam')
#  + variables_(2,_3,_'Science',_'A1',_'Ruti')
#  + variables_(2,_3,_'Science',_'A1',_'Shoshi')
#  + variables_(2,_4,_'Science',_'A1',_'Miriam')
#  + variables_(2,_4,_'Science',_'A1',_'Ruti')
#  + variables_(2,_4,_'Science',_'A1',_'Shoshi')
#  + variables_(2,_5,_'Science',_'A1',_'Miriam')
#  + variables_(2,_5,_'Science',_'A1',_'Ruti')
#  + variables_(2,_5,_'Science',_'A1',_'Shoshi')
#  + variables_(2,_6,_'Science',_'A1',_'Miriam')
#  + variables_(2,_6,_'Science',_'A1',_'Ruti')
#  + variables_(2,_6,_'Science',_'A1',_'Shoshi')
#  + variables_(3,_1,_'Science',_'A1',_'Miriam')
#  + variables_(3,_1,_'Science',_'A1',_'Ruti')
#  + variables_(3,_1,_'Science',_'A1',_'Shoshi')
#  + variables_(3,_2,_'Science',_'A1',_'Miriam')
#  + variables_(3,_2,_'Science',_'A1',_'Ruti')
#  + variables_(3,_2,_'Science',_'A1',_'Shoshi')
#  + variables_(3,_3,_'Science',_'A1',_'Miriam')
#  + variables_(3,_3,_'Science',_'A1',_'Ruti')
#  + variables_(3,_3,_'Science',_'A1',_'Shoshi')
#  + variables_(3,_4,_'Science',_'A1',_'Miriam')
#  + variables_(3,_4,_'Science',_'A1',_'Ruti')
#  + variables_(3,_4,_'Science',_'A1',_'Shoshi')
#  + variables_(3,_5,_'Science',_'A1',_'Miriam')
#  + variables_(3,_5,_'Science',_'A1',_'Ruti')
#  + variables_(3,_5,_'Science',_'A1',_'Shoshi')
#  + variables_(3,_6,_'Science',_'A1',_'Miriam')
#  + variables_(3,_6,_'Science',_'A1',_'Ruti')
#  + variables_(3,_6,_'Science',_'A1',_'Shoshi')
#  + variables_(4,_1,_'Science',_'A1',_'Miriam')
#  + variables_(4,_1,_'Science',_'A1',_'Ruti')
#  + variables_(4,_1,_'Science',_'A1',_'Shoshi')
#  + variables_(4,_2,_'Science',_'A1',_'Miriam')
#  + variables_(4,_2,_'Science',_'A1',_'Ruti')
#  + variables_(4,_2,_'Science',_'A1',_'Shoshi')
#  + variables_(4,_3,_'Science',_'A1',_'Miriam')
#  + variables_(4,_3,_'Science',_'A1',_'Ruti')
#  + variables_(4,_3,_'Science',_'A1',_'Shoshi')
#  + variables_(4,_4,_'Science',_'A1',_'Miriam')
#  + variables_(4,_4,_'Science',_'A1',_'Ruti')
#  + variables_(4,_4,_'Science',_'A1',_'Shoshi')
#  + variables_(4,_5,_'Science',_'A1',_'Miriam')
#  + variables_(4,_5,_'Science',_'A1',_'Ruti')
#  + variables_(4,_5,_'Science',_'A1',_'Shoshi')
#  + variables_(4,_6,_'Science',_'A1',_'Miriam')
#  + variables_(4,_6,_'Science',_'A1',_'Ruti')
#  + variables_(4,_6,_'Science',_'A1',_'Shoshi')
#  + variables_(5,_1,_'Science',_'A1',_'Miriam')
#  + variables_(5,_1,_'Science',_'A1',_'Ruti')
#  + variables_(5,_1,_'Science',_'A1',_'Shoshi')
#  + variables_(5,_2,_'Science',_'A1',_'Miriam')
#  + variables_(5,_2,_'Science',_'A1',_'Ruti')
#  + variables_(5,_2,_'Science',_'A1',_'Shoshi')
#  + variables_(5,_3,_'Science',_'A1',_'Miriam')
#  + variables_(5,_3,_'Science',_'A1',_'Ruti')
#  + variables_(5,_3,_'Science',_'A1',_'Shoshi')
#  + variables_(5,_4,_'Science',_'A1',_'Miriam')
#  + variables_(5,_4,_'Science',_'A1',_'Ruti')
#  + variables_(5,_4,_'Science',_'A1',_'Shoshi')
#  + variables_(5,_5,_'Science',_'A1',_'Miriam')
#  + variables_(5,_5,_'Science',_'A1',_'Ruti')
#  + variables_(5,_5,_'Science',_'A1',_'Shoshi')
#  + variables_(5,_6,_'Science',_'A1',_'Miriam')
#  + variables_(5,_6,_'Science',_'A1',_'Ruti')
#  + variables_(5,_6,_'Science',_'A1',_'Shoshi')
#  + variables_(6,_1,_'Science',_'A1',_'Miriam')
#  + variables_(6,_1,_'Science',_'A1',_'Ruti')
#  + variables_(6,_1,_'Science',_'A1',_'Shoshi')
#  + variables_(6,_2,_'Science',_'A1',_'Miriam')
#  + variables_(6,_2,_'Science',_'A1',_'Ruti')
#  + variables_(6,_2,_'Science',_'A1',_'Shoshi')
#  + variables_(6,_3,_'Science',_'A1',_'Miriam')
#  + variables_(6,_3,_'Science',_'A1',_'Ruti')
#  + variables_(6,_3,_'Science',_'A1',_'Shoshi')
#  + variables_(6,_4,_'Science',_'A1',_'Miriam')
#  + variables_(6,_4,_'Science',_'A1',_'Ruti')
#  + variables_(6,_4,_'Science',_'A1',_'Shoshi')
#  + variables_(6,_5,_'Science',_'A1',_'Miriam')
#  + variables_(6,_5,_'Science',_'A1',_'Ruti')
#  + variables_(6,_5,_'Science',_'A1',_'Shoshi')
#  + variables_(6,_6,_'Science',_'A1',_'Miriam')
#  + variables_(6,_6,_'Science',_'A1',_'Ruti')
#  + variables_(6,_6,_'Science',_'A1',_'Shoshi') = 8
#
# _C3: variables_(1,_1,_'Bible',_'A1',_'Miriam')
#  + variables_(1,_1,_'Bible',_'A1',_'Ruti')
#  + variables_(1,_1,_'Bible',_'A1',_'Shoshi')
#  + variables_(1,_2,_'Bible',_'A1',_'Miriam')
#  + variables_(1,_2,_'Bible',_'A1',_'Ruti')
#  + variables_(1,_2,_'Bible',_'A1',_'Shoshi')
#  + variables_(1,_3,_'Bible',_'A1',_'Miriam')
#  + variables_(1,_3,_'Bible',_'A1',_'Ruti')
#  + variables_(1,_3,_'Bible',_'A1',_'Shoshi')
#  + variables_(1,_4,_'Bible',_'A1',_'Miriam')
#  + variables_(1,_4,_'Bible',_'A1',_'Ruti')
#  + variables_(1,_4,_'Bible',_'A1',_'Shoshi')
#  + variables_(1,_5,_'Bible',_'A1',_'Miriam')
#  + variables_(1,_5,_'Bible',_'A1',_'Ruti')
#  + variables_(1,_5,_'Bible',_'A1',_'Shoshi')
#  + variables_(1,_6,_'Bible',_'A1',_'Miriam')
#  + variables_(1,_6,_'Bible',_'A1',_'Ruti')
#  + variables_(1,_6,_'Bible',_'A1',_'Shoshi')
#  + variables_(2,_1,_'Bible',_'A1',_'Miriam')
#  + variables_(2,_1,_'Bible',_'A1',_'Ruti')
#  + variables_(2,_1,_'Bible',_'A1',_'Shoshi')
#  + variables_(2,_2,_'Bible',_'A1',_'Miriam')
#  + variables_(2,_2,_'Bible',_'A1',_'Ruti')
#  + variables_(2,_2,_'Bible',_'A1',_'Shoshi')
#  + variables_(2,_3,_'Bible',_'A1',_'Miriam')
#  + variables_(2,_3,_'Bible',_'A1',_'Ruti')
#  + variables_(2,_3,_'Bible',_'A1',_'Shoshi')
#  + variables_(2,_4,_'Bible',_'A1',_'Miriam')
#  + variables_(2,_4,_'Bible',_'A1',_'Ruti')
#  + variables_(2,_4,_'Bible',_'A1',_'Shoshi')
#  + variables_(2,_5,_'Bible',_'A1',_'Miriam')
#  + variables_(2,_5,_'Bible',_'A1',_'Ruti')
#  + variables_(2,_5,_'Bible',_'A1',_'Shoshi')
#  + variables_(2,_6,_'Bible',_'A1',_'Miriam')
#  + variables_(2,_6,_'Bible',_'A1',_'Ruti')
#  + variables_(2,_6,_'Bible',_'A1',_'Shoshi')
#  + variables_(3,_1,_'Bible',_'A1',_'Miriam')
#  + variables_(3,_1,_'Bible',_'A1',_'Ruti')
#  + variables_(3,_1,_'Bible',_'A1',_'Shoshi')
#  + variables_(3,_2,_'Bible',_'A1',_'Miriam')
#  + variables_(3,_2,_'Bible',_'A1',_'Ruti')
#  + variables_(3,_2,_'Bible',_'A1',_'Shoshi')
#  + variables_(3,_3,_'Bible',_'A1',_'Miriam')
#  + variables_(3,_3,_'Bible',_'A1',_'Ruti')
#  + variables_(3,_3,_'Bible',_'A1',_'Shoshi')
#  + variables_(3,_4,_'Bible',_'A1',_'Miriam')
#  + variables_(3,_4,_'Bible',_'A1',_'Ruti')
#  + variables_(3,_4,_'Bible',_'A1',_'Shoshi')
#  + variables_(3,_5,_'Bible',_'A1',_'Miriam')
#  + variables_(3,_5,_'Bible',_'A1',_'Ruti')
#  + variables_(3,_5,_'Bible',_'A1',_'Shoshi')
#  + variables_(3,_6,_'Bible',_'A1',_'Miriam')
#  + variables_(3,_6,_'Bible',_'A1',_'Ruti')
#  + variables_(3,_6,_'Bible',_'A1',_'Shoshi')
#  + variables_(4,_1,_'Bible',_'A1',_'Miriam')
#  + variables_(4,_1,_'Bible',_'A1',_'Ruti')
#  + variables_(4,_1,_'Bible',_'A1',_'Shoshi')
#  + variables_(4,_2,_'Bible',_'A1',_'Miriam')
#  + variables_(4,_2,_'Bible',_'A1',_'Ruti')
#  + variables_(4,_2,_'Bible',_'A1',_'Shoshi')
#  + variables_(4,_3,_'Bible',_'A1',_'Miriam')
#  + variables_(4,_3,_'Bible',_'A1',_'Ruti')
#  + variables_(4,_3,_'Bible',_'A1',_'Shoshi')
#  + variables_(4,_4,_'Bible',_'A1',_'Miriam')
#  + variables_(4,_4,_'Bible',_'A1',_'Ruti')
#  + variables_(4,_4,_'Bible',_'A1',_'Shoshi')
#  + variables_(4,_5,_'Bible',_'A1',_'Miriam')
#  + variables_(4,_5,_'Bible',_'A1',_'Ruti')
#  + variables_(4,_5,_'Bible',_'A1',_'Shoshi')
#  + variables_(4,_6,_'Bible',_'A1',_'Miriam')
#  + variables_(4,_6,_'Bible',_'A1',_'Ruti')
#  + variables_(4,_6,_'Bible',_'A1',_'Shoshi')
#  + variables_(5,_1,_'Bible',_'A1',_'Miriam')
#  + variables_(5,_1,_'Bible',_'A1',_'Ruti')
#  + variables_(5,_1,_'Bible',_'A1',_'Shoshi')
#  + variables_(5,_2,_'Bible',_'A1',_'Miriam')
#  + variables_(5,_2,_'Bible',_'A1',_'Ruti')
#  + variables_(5,_2,_'Bible',_'A1',_'Shoshi')
#  + variables_(5,_3,_'Bible',_'A1',_'Miriam')
#  + variables_(5,_3,_'Bible',_'A1',_'Ruti')
#  + variables_(5,_3,_'Bible',_'A1',_'Shoshi')
#  + variables_(5,_4,_'Bible',_'A1',_'Miriam')
#  + variables_(5,_4,_'Bible',_'A1',_'Ruti')
#  + variables_(5,_4,_'Bible',_'A1',_'Shoshi')
#  + variables_(5,_5,_'Bible',_'A1',_'Miriam')
#  + variables_(5,_5,_'Bible',_'A1',_'Ruti')
#  + variables_(5,_5,_'Bible',_'A1',_'Shoshi')
#  + variables_(5,_6,_'Bible',_'A1',_'Miriam')
#  + variables_(5,_6,_'Bible',_'A1',_'Ruti')
#  + variables_(5,_6,_'Bible',_'A1',_'Shoshi')
#  + variables_(6,_1,_'Bible',_'A1',_'Miriam')
#  + variables_(6,_1,_'Bible',_'A1',_'Ruti')
#  + variables_(6,_1,_'Bible',_'A1',_'Shoshi')
#  + variables_(6,_2,_'Bible',_'A1',_'Miriam')
#  + variables_(6,_2,_'Bible',_'A1',_'Ruti')
#  + variables_(6,_2,_'Bible',_'A1',_'Shoshi')
#  + variables_(6,_3,_'Bible',_'A1',_'Miriam')
#  + variables_(6,_3,_'Bible',_'A1',_'Ruti')
#  + variables_(6,_3,_'Bible',_'A1',_'Shoshi')
#  + variables_(6,_4,_'Bible',_'A1',_'Miriam')
#  + variables_(6,_4,_'Bible',_'A1',_'Ruti')
#  + variables_(6,_4,_'Bible',_'A1',_'Shoshi')
#  + variables_(6,_5,_'Bible',_'A1',_'Miriam')
#  + variables_(6,_5,_'Bible',_'A1',_'Ruti')
#  + variables_(6,_5,_'Bible',_'A1',_'Shoshi')
#  + variables_(6,_6,_'Bible',_'A1',_'Miriam')
#  + variables_(6,_6,_'Bible',_'A1',_'Ruti')
#  + variables_(6,_6,_'Bible',_'A1',_'Shoshi') = 8
#
# _C4: variables_(1,_1,_'Math',_'A2',_'Miriam')
#  + variables_(1,_1,_'Math',_'A2',_'Ruti')
#  + variables_(1,_1,_'Math',_'A2',_'Shoshi')
#  + variables_(1,_2,_'Math',_'A2',_'Miriam')
#  + variables_(1,_2,_'Math',_'A2',_'Ruti')
#  + variables_(1,_2,_'Math',_'A2',_'Shoshi')
#  + variables_(1,_3,_'Math',_'A2',_'Miriam')
#  + variables_(1,_3,_'Math',_'A2',_'Ruti')
#  + variables_(1,_3,_'Math',_'A2',_'Shoshi')
#  + variables_(1,_4,_'Math',_'A2',_'Miriam')
#  + variables_(1,_4,_'Math',_'A2',_'Ruti')
#  + variables_(1,_4,_'Math',_'A2',_'Shoshi')
#  + variables_(1,_5,_'Math',_'A2',_'Miriam')
#  + variables_(1,_5,_'Math',_'A2',_'Ruti')
#  + variables_(1,_5,_'Math',_'A2',_'Shoshi')
#  + variables_(1,_6,_'Math',_'A2',_'Miriam')
#  + variables_(1,_6,_'Math',_'A2',_'Ruti')
#  + variables_(1,_6,_'Math',_'A2',_'Shoshi')
#  + variables_(2,_1,_'Math',_'A2',_'Miriam')
#  + variables_(2,_1,_'Math',_'A2',_'Ruti')
#  + variables_(2,_1,_'Math',_'A2',_'Shoshi')
#  + variables_(2,_2,_'Math',_'A2',_'Miriam')
#  + variables_(2,_2,_'Math',_'A2',_'Ruti')
#  + variables_(2,_2,_'Math',_'A2',_'Shoshi')
#  + variables_(2,_3,_'Math',_'A2',_'Miriam')
#  + variables_(2,_3,_'Math',_'A2',_'Ruti')
#  + variables_(2,_3,_'Math',_'A2',_'Shoshi')
#  + variables_(2,_4,_'Math',_'A2',_'Miriam')
#  + variables_(2,_4,_'Math',_'A2',_'Ruti')
#  + variables_(2,_4,_'Math',_'A2',_'Shoshi')
#  + variables_(2,_5,_'Math',_'A2',_'Miriam')
#  + variables_(2,_5,_'Math',_'A2',_'Ruti')
#  + variables_(2,_5,_'Math',_'A2',_'Shoshi')
#  + variables_(2,_6,_'Math',_'A2',_'Miriam')
#  + variables_(2,_6,_'Math',_'A2',_'Ruti')
#  + variables_(2,_6,_'Math',_'A2',_'Shoshi')
#  + variables_(3,_1,_'Math',_'A2',_'Miriam')
#  + variables_(3,_1,_'Math',_'A2',_'Ruti')
#  + variables_(3,_1,_'Math',_'A2',_'Shoshi')
#  + variables_(3,_2,_'Math',_'A2',_'Miriam')
#  + variables_(3,_2,_'Math',_'A2',_'Ruti')
#  + variables_(3,_2,_'Math',_'A2',_'Shoshi')
#  + variables_(3,_3,_'Math',_'A2',_'Miriam')
#  + variables_(3,_3,_'Math',_'A2',_'Ruti')
#  + variables_(3,_3,_'Math',_'A2',_'Shoshi')
#  + variables_(3,_4,_'Math',_'A2',_'Miriam')
#  + variables_(3,_4,_'Math',_'A2',_'Ruti')
#  + variables_(3,_4,_'Math',_'A2',_'Shoshi')
#  + variables_(3,_5,_'Math',_'A2',_'Miriam')
#  + variables_(3,_5,_'Math',_'A2',_'Ruti')
#  + variables_(3,_5,_'Math',_'A2',_'Shoshi')
#  + variables_(3,_6,_'Math',_'A2',_'Miriam')
#  + variables_(3,_6,_'Math',_'A2',_'Ruti')
#  + variables_(3,_6,_'Math',_'A2',_'Shoshi')
#  + variables_(4,_1,_'Math',_'A2',_'Miriam')
#  + variables_(4,_1,_'Math',_'A2',_'Ruti')
#  + variables_(4,_1,_'Math',_'A2',_'Shoshi')
#  + variables_(4,_2,_'Math',_'A2',_'Miriam')
#  + variables_(4,_2,_'Math',_'A2',_'Ruti')
#  + variables_(4,_2,_'Math',_'A2',_'Shoshi')
#  + variables_(4,_3,_'Math',_'A2',_'Miriam')
#  + variables_(4,_3,_'Math',_'A2',_'Ruti')
#  + variables_(4,_3,_'Math',_'A2',_'Shoshi')
#  + variables_(4,_4,_'Math',_'A2',_'Miriam')
#  + variables_(4,_4,_'Math',_'A2',_'Ruti')
#  + variables_(4,_4,_'Math',_'A2',_'Shoshi')
#  + variables_(4,_5,_'Math',_'A2',_'Miriam')
#  + variables_(4,_5,_'Math',_'A2',_'Ruti')
#  + variables_(4,_5,_'Math',_'A2',_'Shoshi')
#  + variables_(4,_6,_'Math',_'A2',_'Miriam')
#  + variables_(4,_6,_'Math',_'A2',_'Ruti')
#  + variables_(4,_6,_'Math',_'A2',_'Shoshi')
#  + variables_(5,_1,_'Math',_'A2',_'Miriam')
#  + variables_(5,_1,_'Math',_'A2',_'Ruti')
#  + variables_(5,_1,_'Math',_'A2',_'Shoshi')
#  + variables_(5,_2,_'Math',_'A2',_'Miriam')
#  + variables_(5,_2,_'Math',_'A2',_'Ruti')
#  + variables_(5,_2,_'Math',_'A2',_'Shoshi')
#  + variables_(5,_3,_'Math',_'A2',_'Miriam')
#  + variables_(5,_3,_'Math',_'A2',_'Ruti')
#  + variables_(5,_3,_'Math',_'A2',_'Shoshi')
#  + variables_(5,_4,_'Math',_'A2',_'Miriam')
#  + variables_(5,_4,_'Math',_'A2',_'Ruti')
#  + variables_(5,_4,_'Math',_'A2',_'Shoshi')
#  + variables_(5,_5,_'Math',_'A2',_'Miriam')
#  + variables_(5,_5,_'Math',_'A2',_'Ruti')
#  + variables_(5,_5,_'Math',_'A2',_'Shoshi')
#  + variables_(5,_6,_'Math',_'A2',_'Miriam')
#  + variables_(5,_6,_'Math',_'A2',_'Ruti')
#  + variables_(5,_6,_'Math',_'A2',_'Shoshi')
#  + variables_(6,_1,_'Math',_'A2',_'Miriam')
#  + variables_(6,_1,_'Math',_'A2',_'Ruti')
#  + variables_(6,_1,_'Math',_'A2',_'Shoshi')
#  + variables_(6,_2,_'Math',_'A2',_'Miriam')
#  + variables_(6,_2,_'Math',_'A2',_'Ruti')
#  + variables_(6,_2,_'Math',_'A2',_'Shoshi')
#  + variables_(6,_3,_'Math',_'A2',_'Miriam')
#  + variables_(6,_3,_'Math',_'A2',_'Ruti')
#  + variables_(6,_3,_'Math',_'A2',_'Shoshi')
#  + variables_(6,_4,_'Math',_'A2',_'Miriam')
#  + variables_(6,_4,_'Math',_'A2',_'Ruti')
#  + variables_(6,_4,_'Math',_'A2',_'Shoshi')
#  + variables_(6,_5,_'Math',_'A2',_'Miriam')
#  + variables_(6,_5,_'Math',_'A2',_'Ruti')
#  + variables_(6,_5,_'Math',_'A2',_'Shoshi')
#  + variables_(6,_6,_'Math',_'A2',_'Miriam')
#  + variables_(6,_6,_'Math',_'A2',_'Ruti')
#  + variables_(6,_6,_'Math',_'A2',_'Shoshi') = 8
#
# _C5: variables_(1,_1,_'Science',_'A2',_'Miriam')
#  + variables_(1,_1,_'Science',_'A2',_'Ruti')
#  + variables_(1,_1,_'Science',_'A2',_'Shoshi')
#  + variables_(1,_2,_'Science',_'A2',_'Miriam')
#  + variables_(1,_2,_'Science',_'A2',_'Ruti')
#  + variables_(1,_2,_'Science',_'A2',_'Shoshi')
#  + variables_(1,_3,_'Science',_'A2',_'Miriam')
#  + variables_(1,_3,_'Science',_'A2',_'Ruti')
#  + variables_(1,_3,_'Science',_'A2',_'Shoshi')
#  + variables_(1,_4,_'Science',_'A2',_'Miriam')
#  + variables_(1,_4,_'Science',_'A2',_'Ruti')
#  + variables_(1,_4,_'Science',_'A2',_'Shoshi')
#  + variables_(1,_5,_'Science',_'A2',_'Miriam')
#  + variables_(1,_5,_'Science',_'A2',_'Ruti')
#  + variables_(1,_5,_'Science',_'A2',_'Shoshi')
#  + variables_(1,_6,_'Science',_'A2',_'Miriam')
#  + variables_(1,_6,_'Science',_'A2',_'Ruti')
#  + variables_(1,_6,_'Science',_'A2',_'Shoshi')
#  + variables_(2,_1,_'Science',_'A2',_'Miriam')
#  + variables_(2,_1,_'Science',_'A2',_'Ruti')
#  + variables_(2,_1,_'Science',_'A2',_'Shoshi')
#  + variables_(2,_2,_'Science',_'A2',_'Miriam')
#  + variables_(2,_2,_'Science',_'A2',_'Ruti')
#  + variables_(2,_2,_'Science',_'A2',_'Shoshi')
#  + variables_(2,_3,_'Science',_'A2',_'Miriam')
#  + variables_(2,_3,_'Science',_'A2',_'Ruti')
#  + variables_(2,_3,_'Science',_'A2',_'Shoshi')
#  + variables_(2,_4,_'Science',_'A2',_'Miriam')
#  + variables_(2,_4,_'Science',_'A2',_'Ruti')
#  + variables_(2,_4,_'Science',_'A2',_'Shoshi')
#  + variables_(2,_5,_'Science',_'A2',_'Miriam')
#  + variables_(2,_5,_'Science',_'A2',_'Ruti')
#  + variables_(2,_5,_'Science',_'A2',_'Shoshi')
#  + variables_(2,_6,_'Science',_'A2',_'Miriam')
#  + variables_(2,_6,_'Science',_'A2',_'Ruti')
#  + variables_(2,_6,_'Science',_'A2',_'Shoshi')
#  + variables_(3,_1,_'Science',_'A2',_'Miriam')
#  + variables_(3,_1,_'Science',_'A2',_'Ruti')
#  + variables_(3,_1,_'Science',_'A2',_'Shoshi')
#  + variables_(3,_2,_'Science',_'A2',_'Miriam')
#  + variables_(3,_2,_'Science',_'A2',_'Ruti')
#  + variables_(3,_2,_'Science',_'A2',_'Shoshi')
#  + variables_(3,_3,_'Science',_'A2',_'Miriam')
#  + variables_(3,_3,_'Science',_'A2',_'Ruti')
#  + variables_(3,_3,_'Science',_'A2',_'Shoshi')
#  + variables_(3,_4,_'Science',_'A2',_'Miriam')
#  + variables_(3,_4,_'Science',_'A2',_'Ruti')
#  + variables_(3,_4,_'Science',_'A2',_'Shoshi')
#  + variables_(3,_5,_'Science',_'A2',_'Miriam')
#  + variables_(3,_5,_'Science',_'A2',_'Ruti')
#  + variables_(3,_5,_'Science',_'A2',_'Shoshi')
#  + variables_(3,_6,_'Science',_'A2',_'Miriam')
#  + variables_(3,_6,_'Science',_'A2',_'Ruti')
#  + variables_(3,_6,_'Science',_'A2',_'Shoshi')
#  + variables_(4,_1,_'Science',_'A2',_'Miriam')
#  + variables_(4,_1,_'Science',_'A2',_'Ruti')
#  + variables_(4,_1,_'Science',_'A2',_'Shoshi')
#  + variables_(4,_2,_'Science',_'A2',_'Miriam')
#  + variables_(4,_2,_'Science',_'A2',_'Ruti')
#  + variables_(4,_2,_'Science',_'A2',_'Shoshi')
#  + variables_(4,_3,_'Science',_'A2',_'Miriam')
#  + variables_(4,_3,_'Science',_'A2',_'Ruti')
#  + variables_(4,_3,_'Science',_'A2',_'Shoshi')
#  + variables_(4,_4,_'Science',_'A2',_'Miriam')
#  + variables_(4,_4,_'Science',_'A2',_'Ruti')
#  + variables_(4,_4,_'Science',_'A2',_'Shoshi')
#  + variables_(4,_5,_'Science',_'A2',_'Miriam')
#  + variables_(4,_5,_'Science',_'A2',_'Ruti')
#  + variables_(4,_5,_'Science',_'A2',_'Shoshi')
#  + variables_(4,_6,_'Science',_'A2',_'Miriam')
#  + variables_(4,_6,_'Science',_'A2',_'Ruti')
#  + variables_(4,_6,_'Science',_'A2',_'Shoshi')
#  + variables_(5,_1,_'Science',_'A2',_'Miriam')
#  + variables_(5,_1,_'Science',_'A2',_'Ruti')
#  + variables_(5,_1,_'Science',_'A2',_'Shoshi')
#  + variables_(5,_2,_'Science',_'A2',_'Miriam')
#  + variables_(5,_2,_'Science',_'A2',_'Ruti')
#  + variables_(5,_2,_'Science',_'A2',_'Shoshi')
#  + variables_(5,_3,_'Science',_'A2',_'Miriam')
#  + variables_(5,_3,_'Science',_'A2',_'Ruti')
#  + variables_(5,_3,_'Science',_'A2',_'Shoshi')
#  + variables_(5,_4,_'Science',_'A2',_'Miriam')
#  + variables_(5,_4,_'Science',_'A2',_'Ruti')
#  + variables_(5,_4,_'Science',_'A2',_'Shoshi')
#  + variables_(5,_5,_'Science',_'A2',_'Miriam')
#  + variables_(5,_5,_'Science',_'A2',_'Ruti')
#  + variables_(5,_5,_'Science',_'A2',_'Shoshi')
#  + variables_(5,_6,_'Science',_'A2',_'Miriam')
#  + variables_(5,_6,_'Science',_'A2',_'Ruti')
#  + variables_(5,_6,_'Science',_'A2',_'Shoshi')
#  + variables_(6,_1,_'Science',_'A2',_'Miriam')
#  + variables_(6,_1,_'Science',_'A2',_'Ruti')
#  + variables_(6,_1,_'Science',_'A2',_'Shoshi')
#  + variables_(6,_2,_'Science',_'A2',_'Miriam')
#  + variables_(6,_2,_'Science',_'A2',_'Ruti')
#  + variables_(6,_2,_'Science',_'A2',_'Shoshi')
#  + variables_(6,_3,_'Science',_'A2',_'Miriam')
#  + variables_(6,_3,_'Science',_'A2',_'Ruti')
#  + variables_(6,_3,_'Science',_'A2',_'Shoshi')
#  + variables_(6,_4,_'Science',_'A2',_'Miriam')
#  + variables_(6,_4,_'Science',_'A2',_'Ruti')
#  + variables_(6,_4,_'Science',_'A2',_'Shoshi')
#  + variables_(6,_5,_'Science',_'A2',_'Miriam')
#  + variables_(6,_5,_'Science',_'A2',_'Ruti')
#  + variables_(6,_5,_'Science',_'A2',_'Shoshi')
#  + variables_(6,_6,_'Science',_'A2',_'Miriam')
#  + variables_(6,_6,_'Science',_'A2',_'Ruti')
#  + variables_(6,_6,_'Science',_'A2',_'Shoshi') = 8
#
# _C6: variables_(1,_1,_'Bible',_'A2',_'Miriam')
#  + variables_(1,_1,_'Bible',_'A2',_'Ruti')
#  + variables_(1,_1,_'Bible',_'A2',_'Shoshi')
#  + variables_(1,_2,_'Bible',_'A2',_'Miriam')
#  + variables_(1,_2,_'Bible',_'A2',_'Ruti')
#  + variables_(1,_2,_'Bible',_'A2',_'Shoshi')
#  + variables_(1,_3,_'Bible',_'A2',_'Miriam')
#  + variables_(1,_3,_'Bible',_'A2',_'Ruti')
#  + variables_(1,_3,_'Bible',_'A2',_'Shoshi')
#  + variables_(1,_4,_'Bible',_'A2',_'Miriam')
#  + variables_(1,_4,_'Bible',_'A2',_'Ruti')
#  + variables_(1,_4,_'Bible',_'A2',_'Shoshi')
#  + variables_(1,_5,_'Bible',_'A2',_'Miriam')
#  + variables_(1,_5,_'Bible',_'A2',_'Ruti')
#  + variables_(1,_5,_'Bible',_'A2',_'Shoshi')
#  + variables_(1,_6,_'Bible',_'A2',_'Miriam')
#  + variables_(1,_6,_'Bible',_'A2',_'Ruti')
#  + variables_(1,_6,_'Bible',_'A2',_'Shoshi')
#  + variables_(2,_1,_'Bible',_'A2',_'Miriam')
#  + variables_(2,_1,_'Bible',_'A2',_'Ruti')
#  + variables_(2,_1,_'Bible',_'A2',_'Shoshi')
#  + variables_(2,_2,_'Bible',_'A2',_'Miriam')
#  + variables_(2,_2,_'Bible',_'A2',_'Ruti')
#  + variables_(2,_2,_'Bible',_'A2',_'Shoshi')
#  + variables_(2,_3,_'Bible',_'A2',_'Miriam')
#  + variables_(2,_3,_'Bible',_'A2',_'Ruti')
#  + variables_(2,_3,_'Bible',_'A2',_'Shoshi')
#  + variables_(2,_4,_'Bible',_'A2',_'Miriam')
#  + variables_(2,_4,_'Bible',_'A2',_'Ruti')
#  + variables_(2,_4,_'Bible',_'A2',_'Shoshi')
#  + variables_(2,_5,_'Bible',_'A2',_'Miriam')
#  + variables_(2,_5,_'Bible',_'A2',_'Ruti')
#  + variables_(2,_5,_'Bible',_'A2',_'Shoshi')
#  + variables_(2,_6,_'Bible',_'A2',_'Miriam')
#  + variables_(2,_6,_'Bible',_'A2',_'Ruti')
#  + variables_(2,_6,_'Bible',_'A2',_'Shoshi')
#  + variables_(3,_1,_'Bible',_'A2',_'Miriam')
#  + variables_(3,_1,_'Bible',_'A2',_'Ruti')
#  + variables_(3,_1,_'Bible',_'A2',_'Shoshi')
#  + variables_(3,_2,_'Bible',_'A2',_'Miriam')
#  + variables_(3,_2,_'Bible',_'A2',_'Ruti')
#  + variables_(3,_2,_'Bible',_'A2',_'Shoshi')
#  + variables_(3,_3,_'Bible',_'A2',_'Miriam')
#  + variables_(3,_3,_'Bible',_'A2',_'Ruti')
#  + variables_(3,_3,_'Bible',_'A2',_'Shoshi')
#  + variables_(3,_4,_'Bible',_'A2',_'Miriam')
#  + variables_(3,_4,_'Bible',_'A2',_'Ruti')
#  + variables_(3,_4,_'Bible',_'A2',_'Shoshi')
#  + variables_(3,_5,_'Bible',_'A2',_'Miriam')
#  + variables_(3,_5,_'Bible',_'A2',_'Ruti')
#  + variables_(3,_5,_'Bible',_'A2',_'Shoshi')
#  + variables_(3,_6,_'Bible',_'A2',_'Miriam')
#  + variables_(3,_6,_'Bible',_'A2',_'Ruti')
#  + variables_(3,_6,_'Bible',_'A2',_'Shoshi')
#  + variables_(4,_1,_'Bible',_'A2',_'Miriam')
#  + variables_(4,_1,_'Bible',_'A2',_'Ruti')
#  + variables_(4,_1,_'Bible',_'A2',_'Shoshi')
#  + variables_(4,_2,_'Bible',_'A2',_'Miriam')
#  + variables_(4,_2,_'Bible',_'A2',_'Ruti')
#  + variables_(4,_2,_'Bible',_'A2',_'Shoshi')
#  + variables_(4,_3,_'Bible',_'A2',_'Miriam')
#  + variables_(4,_3,_'Bible',_'A2',_'Ruti')
#  + variables_(4,_3,_'Bible',_'A2',_'Shoshi')
#  + variables_(4,_4,_'Bible',_'A2',_'Miriam')
#  + variables_(4,_4,_'Bible',_'A2',_'Ruti')
#  + variables_(4,_4,_'Bible',_'A2',_'Shoshi')
#  + variables_(4,_5,_'Bible',_'A2',_'Miriam')
#  + variables_(4,_5,_'Bible',_'A2',_'Ruti')
#  + variables_(4,_5,_'Bible',_'A2',_'Shoshi')
#  + variables_(4,_6,_'Bible',_'A2',_'Miriam')
#  + variables_(4,_6,_'Bible',_'A2',_'Ruti')
#  + variables_(4,_6,_'Bible',_'A2',_'Shoshi')
#  + variables_(5,_1,_'Bible',_'A2',_'Miriam')
#  + variables_(5,_1,_'Bible',_'A2',_'Ruti')
#  + variables_(5,_1,_'Bible',_'A2',_'Shoshi')
#  + variables_(5,_2,_'Bible',_'A2',_'Miriam')
#  + variables_(5,_2,_'Bible',_'A2',_'Ruti')
#  + variables_(5,_2,_'Bible',_'A2',_'Shoshi')
#  + variables_(5,_3,_'Bible',_'A2',_'Miriam')
#  + variables_(5,_3,_'Bible',_'A2',_'Ruti')
#  + variables_(5,_3,_'Bible',_'A2',_'Shoshi')
#  + variables_(5,_4,_'Bible',_'A2',_'Miriam')
#  + variables_(5,_4,_'Bible',_'A2',_'Ruti')
#  + variables_(5,_4,_'Bible',_'A2',_'Shoshi')
#  + variables_(5,_5,_'Bible',_'A2',_'Miriam')
#  + variables_(5,_5,_'Bible',_'A2',_'Ruti')
#  + variables_(5,_5,_'Bible',_'A2',_'Shoshi')
#  + variables_(5,_6,_'Bible',_'A2',_'Miriam')
#  + variables_(5,_6,_'Bible',_'A2',_'Ruti')
#  + variables_(5,_6,_'Bible',_'A2',_'Shoshi')
#  + variables_(6,_1,_'Bible',_'A2',_'Miriam')
#  + variables_(6,_1,_'Bible',_'A2',_'Ruti')
#  + variables_(6,_1,_'Bible',_'A2',_'Shoshi')
#  + variables_(6,_2,_'Bible',_'A2',_'Miriam')
#  + variables_(6,_2,_'Bible',_'A2',_'Ruti')
#  + variables_(6,_2,_'Bible',_'A2',_'Shoshi')
#  + variables_(6,_3,_'Bible',_'A2',_'Miriam')
#  + variables_(6,_3,_'Bible',_'A2',_'Ruti')
#  + variables_(6,_3,_'Bible',_'A2',_'Shoshi')
#  + variables_(6,_4,_'Bible',_'A2',_'Miriam')
#  + variables_(6,_4,_'Bible',_'A2',_'Ruti')
#  + variables_(6,_4,_'Bible',_'A2',_'Shoshi')
#  + variables_(6,_5,_'Bible',_'A2',_'Miriam')
#  + variables_(6,_5,_'Bible',_'A2',_'Ruti')
#  + variables_(6,_5,_'Bible',_'A2',_'Shoshi')
#  + variables_(6,_6,_'Bible',_'A2',_'Miriam')
#  + variables_(6,_6,_'Bible',_'A2',_'Ruti')
#  + variables_(6,_6,_'Bible',_'A2',_'Shoshi') = 8
#
# _C7: variables_(1,_1,_'Math',_'A3',_'Miriam')
#  + variables_(1,_1,_'Math',_'A3',_'Ruti')
#  + variables_(1,_1,_'Math',_'A3',_'Shoshi')
#  + variables_(1,_2,_'Math',_'A3',_'Miriam')
#  + variables_(1,_2,_'Math',_'A3',_'Ruti')
#  + variables_(1,_2,_'Math',_'A3',_'Shoshi')
#  + variables_(1,_3,_'Math',_'A3',_'Miriam')
#  + variables_(1,_3,_'Math',_'A3',_'Ruti')
#  + variables_(1,_3,_'Math',_'A3',_'Shoshi')
#  + variables_(1,_4,_'Math',_'A3',_'Miriam')
#  + variables_(1,_4,_'Math',_'A3',_'Ruti')
#  + variables_(1,_4,_'Math',_'A3',_'Shoshi')
#  + variables_(1,_5,_'Math',_'A3',_'Miriam')
#  + variables_(1,_5,_'Math',_'A3',_'Ruti')
#  + variables_(1,_5,_'Math',_'A3',_'Shoshi')
#  + variables_(1,_6,_'Math',_'A3',_'Miriam')
#  + variables_(1,_6,_'Math',_'A3',_'Ruti')
#  + variables_(1,_6,_'Math',_'A3',_'Shoshi')
#  + variables_(2,_1,_'Math',_'A3',_'Miriam')
#  + variables_(2,_1,_'Math',_'A3',_'Ruti')
#  + variables_(2,_1,_'Math',_'A3',_'Shoshi')
#  + variables_(2,_2,_'Math',_'A3',_'Miriam')
#  + variables_(2,_2,_'Math',_'A3',_'Ruti')
#  + variables_(2,_2,_'Math',_'A3',_'Shoshi')
#  + variables_(2,_3,_'Math',_'A3',_'Miriam')
#  + variables_(2,_3,_'Math',_'A3',_'Ruti')
#  + variables_(2,_3,_'Math',_'A3',_'Shoshi')
#  + variables_(2,_4,_'Math',_'A3',_'Miriam')
#  + variables_(2,_4,_'Math',_'A3',_'Ruti')
#  + variables_(2,_4,_'Math',_'A3',_'Shoshi')
#  + variables_(2,_5,_'Math',_'A3',_'Miriam')
#  + variables_(2,_5,_'Math',_'A3',_'Ruti')
#  + variables_(2,_5,_'Math',_'A3',_'Shoshi')
#  + variables_(2,_6,_'Math',_'A3',_'Miriam')
#  + variables_(2,_6,_'Math',_'A3',_'Ruti')
#  + variables_(2,_6,_'Math',_'A3',_'Shoshi')
#  + variables_(3,_1,_'Math',_'A3',_'Miriam')
#  + variables_(3,_1,_'Math',_'A3',_'Ruti')
#  + variables_(3,_1,_'Math',_'A3',_'Shoshi')
#  + variables_(3,_2,_'Math',_'A3',_'Miriam')
#  + variables_(3,_2,_'Math',_'A3',_'Ruti')
#  + variables_(3,_2,_'Math',_'A3',_'Shoshi')
#  + variables_(3,_3,_'Math',_'A3',_'Miriam')
#  + variables_(3,_3,_'Math',_'A3',_'Ruti')
#  + variables_(3,_3,_'Math',_'A3',_'Shoshi')
#  + variables_(3,_4,_'Math',_'A3',_'Miriam')
#  + variables_(3,_4,_'Math',_'A3',_'Ruti')
#  + variables_(3,_4,_'Math',_'A3',_'Shoshi')
#  + variables_(3,_5,_'Math',_'A3',_'Miriam')
#  + variables_(3,_5,_'Math',_'A3',_'Ruti')
#  + variables_(3,_5,_'Math',_'A3',_'Shoshi')
#  + variables_(3,_6,_'Math',_'A3',_'Miriam')
#  + variables_(3,_6,_'Math',_'A3',_'Ruti')
#  + variables_(3,_6,_'Math',_'A3',_'Shoshi')
#  + variables_(4,_1,_'Math',_'A3',_'Miriam')
#  + variables_(4,_1,_'Math',_'A3',_'Ruti')
#  + variables_(4,_1,_'Math',_'A3',_'Shoshi')
#  + variables_(4,_2,_'Math',_'A3',_'Miriam')
#  + variables_(4,_2,_'Math',_'A3',_'Ruti')
#  + variables_(4,_2,_'Math',_'A3',_'Shoshi')
#  + variables_(4,_3,_'Math',_'A3',_'Miriam')
#  + variables_(4,_3,_'Math',_'A3',_'Ruti')
#  + variables_(4,_3,_'Math',_'A3',_'Shoshi')
#  + variables_(4,_4,_'Math',_'A3',_'Miriam')
#  + variables_(4,_4,_'Math',_'A3',_'Ruti')
#  + variables_(4,_4,_'Math',_'A3',_'Shoshi')
#  + variables_(4,_5,_'Math',_'A3',_'Miriam')
#  + variables_(4,_5,_'Math',_'A3',_'Ruti')
#  + variables_(4,_5,_'Math',_'A3',_'Shoshi')
#  + variables_(4,_6,_'Math',_'A3',_'Miriam')
#  + variables_(4,_6,_'Math',_'A3',_'Ruti')
#  + variables_(4,_6,_'Math',_'A3',_'Shoshi')
#  + variables_(5,_1,_'Math',_'A3',_'Miriam')
#  + variables_(5,_1,_'Math',_'A3',_'Ruti')
#  + variables_(5,_1,_'Math',_'A3',_'Shoshi')
#  + variables_(5,_2,_'Math',_'A3',_'Miriam')
#  + variables_(5,_2,_'Math',_'A3',_'Ruti')
#  + variables_(5,_2,_'Math',_'A3',_'Shoshi')
#  + variables_(5,_3,_'Math',_'A3',_'Miriam')
#  + variables_(5,_3,_'Math',_'A3',_'Ruti')
#  + variables_(5,_3,_'Math',_'A3',_'Shoshi')
#  + variables_(5,_4,_'Math',_'A3',_'Miriam')
#  + variables_(5,_4,_'Math',_'A3',_'Ruti')
#  + variables_(5,_4,_'Math',_'A3',_'Shoshi')
#  + variables_(5,_5,_'Math',_'A3',_'Miriam')
#  + variables_(5,_5,_'Math',_'A3',_'Ruti')
#  + variables_(5,_5,_'Math',_'A3',_'Shoshi')
#  + variables_(5,_6,_'Math',_'A3',_'Miriam')
#  + variables_(5,_6,_'Math',_'A3',_'Ruti')
#  + variables_(5,_6,_'Math',_'A3',_'Shoshi')
#  + variables_(6,_1,_'Math',_'A3',_'Miriam')
#  + variables_(6,_1,_'Math',_'A3',_'Ruti')
#  + variables_(6,_1,_'Math',_'A3',_'Shoshi')
#  + variables_(6,_2,_'Math',_'A3',_'Miriam')
#  + variables_(6,_2,_'Math',_'A3',_'Ruti')
#  + variables_(6,_2,_'Math',_'A3',_'Shoshi')
#  + variables_(6,_3,_'Math',_'A3',_'Miriam')
#  + variables_(6,_3,_'Math',_'A3',_'Ruti')
#  + variables_(6,_3,_'Math',_'A3',_'Shoshi')
#  + variables_(6,_4,_'Math',_'A3',_'Miriam')
#  + variables_(6,_4,_'Math',_'A3',_'Ruti')
#  + variables_(6,_4,_'Math',_'A3',_'Shoshi')
#  + variables_(6,_5,_'Math',_'A3',_'Miriam')
#  + variables_(6,_5,_'Math',_'A3',_'Ruti')
#  + variables_(6,_5,_'Math',_'A3',_'Shoshi')
#  + variables_(6,_6,_'Math',_'A3',_'Miriam')
#  + variables_(6,_6,_'Math',_'A3',_'Ruti')
#  + variables_(6,_6,_'Math',_'A3',_'Shoshi') = 8
#
# _C8: variables_(1,_1,_'Science',_'A3',_'Miriam')
#  + variables_(1,_1,_'Science',_'A3',_'Ruti')
#  + variables_(1,_1,_'Science',_'A3',_'Shoshi')
#  + variables_(1,_2,_'Science',_'A3',_'Miriam')
#  + variables_(1,_2,_'Science',_'A3',_'Ruti')
#  + variables_(1,_2,_'Science',_'A3',_'Shoshi')
#  + variables_(1,_3,_'Science',_'A3',_'Miriam')
#  + variables_(1,_3,_'Science',_'A3',_'Ruti')
#  + variables_(1,_3,_'Science',_'A3',_'Shoshi')
#  + variables_(1,_4,_'Science',_'A3',_'Miriam')
#  + variables_(1,_4,_'Science',_'A3',_'Ruti')
#  + variables_(1,_4,_'Science',_'A3',_'Shoshi')
#  + variables_(1,_5,_'Science',_'A3',_'Miriam')
#  + variables_(1,_5,_'Science',_'A3',_'Ruti')
#  + variables_(1,_5,_'Science',_'A3',_'Shoshi')
#  + variables_(1,_6,_'Science',_'A3',_'Miriam')
#  + variables_(1,_6,_'Science',_'A3',_'Ruti')
#  + variables_(1,_6,_'Science',_'A3',_'Shoshi')
#  + variables_(2,_1,_'Science',_'A3',_'Miriam')
#  + variables_(2,_1,_'Science',_'A3',_'Ruti')
#  + variables_(2,_1,_'Science',_'A3',_'Shoshi')
#  + variables_(2,_2,_'Science',_'A3',_'Miriam')
#  + variables_(2,_2,_'Science',_'A3',_'Ruti')
#  + variables_(2,_2,_'Science',_'A3',_'Shoshi')
#  + variables_(2,_3,_'Science',_'A3',_'Miriam')
#  + variables_(2,_3,_'Science',_'A3',_'Ruti')
#  + variables_(2,_3,_'Science',_'A3',_'Shoshi')
#  + variables_(2,_4,_'Science',_'A3',_'Miriam')
#  + variables_(2,_4,_'Science',_'A3',_'Ruti')
#  + variables_(2,_4,_'Science',_'A3',_'Shoshi')
#  + variables_(2,_5,_'Science',_'A3',_'Miriam')
#  + variables_(2,_5,_'Science',_'A3',_'Ruti')
#  + variables_(2,_5,_'Science',_'A3',_'Shoshi')
#  + variables_(2,_6,_'Science',_'A3',_'Miriam')
#  + variables_(2,_6,_'Science',_'A3',_'Ruti')
#  + variables_(2,_6,_'Science',_'A3',_'Shoshi')
#  + variables_(3,_1,_'Science',_'A3',_'Miriam')
#  + variables_(3,_1,_'Science',_'A3',_'Ruti')
#  + variables_(3,_1,_'Science',_'A3',_'Shoshi')
#  + variables_(3,_2,_'Science',_'A3',_'Miriam')
#  + variables_(3,_2,_'Science',_'A3',_'Ruti')
#  + variables_(3,_2,_'Science',_'A3',_'Shoshi')
#  + variables_(3,_3,_'Science',_'A3',_'Miriam')
#  + variables_(3,_3,_'Science',_'A3',_'Ruti')
#  + variables_(3,_3,_'Science',_'A3',_'Shoshi')
#  + variables_(3,_4,_'Science',_'A3',_'Miriam')
#  + variables_(3,_4,_'Science',_'A3',_'Ruti')
#  + variables_(3,_4,_'Science',_'A3',_'Shoshi')
#  + variables_(3,_5,_'Science',_'A3',_'Miriam')
#  + variables_(3,_5,_'Science',_'A3',_'Ruti')
#  + variables_(3,_5,_'Science',_'A3',_'Shoshi')
#  + variables_(3,_6,_'Science',_'A3',_'Miriam')
#  + variables_(3,_6,_'Science',_'A3',_'Ruti')
#  + variables_(3,_6,_'Science',_'A3',_'Shoshi')
#  + variables_(4,_1,_'Science',_'A3',_'Miriam')
#  + variables_(4,_1,_'Science',_'A3',_'Ruti')
#  + variables_(4,_1,_'Science',_'A3',_'Shoshi')
#  + variables_(4,_2,_'Science',_'A3',_'Miriam')
#  + variables_(4,_2,_'Science',_'A3',_'Ruti')
#  + variables_(4,_2,_'Science',_'A3',_'Shoshi')
#  + variables_(4,_3,_'Science',_'A3',_'Miriam')
#  + variables_(4,_3,_'Science',_'A3',_'Ruti')
#  + variables_(4,_3,_'Science',_'A3',_'Shoshi')
#  + variables_(4,_4,_'Science',_'A3',_'Miriam')
#  + variables_(4,_4,_'Science',_'A3',_'Ruti')
#  + variables_(4,_4,_'Science',_'A3',_'Shoshi')
#  + variables_(4,_5,_'Science',_'A3',_'Miriam')
#  + variables_(4,_5,_'Science',_'A3',_'Ruti')
#  + variables_(4,_5,_'Science',_'A3',_'Shoshi')
#  + variables_(4,_6,_'Science',_'A3',_'Miriam')
#  + variables_(4,_6,_'Science',_'A3',_'Ruti')
#  + variables_(4,_6,_'Science',_'A3',_'Shoshi')
#  + variables_(5,_1,_'Science',_'A3',_'Miriam')
#  + variables_(5,_1,_'Science',_'A3',_'Ruti')
#  + variables_(5,_1,_'Science',_'A3',_'Shoshi')
#  + variables_(5,_2,_'Science',_'A3',_'Miriam')
#  + variables_(5,_2,_'Science',_'A3',_'Ruti')
#  + variables_(5,_2,_'Science',_'A3',_'Shoshi')
#  + variables_(5,_3,_'Science',_'A3',_'Miriam')
#  + variables_(5,_3,_'Science',_'A3',_'Ruti')
#  + variables_(5,_3,_'Science',_'A3',_'Shoshi')
#  + variables_(5,_4,_'Science',_'A3',_'Miriam')
#  + variables_(5,_4,_'Science',_'A3',_'Ruti')
#  + variables_(5,_4,_'Science',_'A3',_'Shoshi')
#  + variables_(5,_5,_'Science',_'A3',_'Miriam')
#  + variables_(5,_5,_'Science',_'A3',_'Ruti')
#  + variables_(5,_5,_'Science',_'A3',_'Shoshi')
#  + variables_(5,_6,_'Science',_'A3',_'Miriam')
#  + variables_(5,_6,_'Science',_'A3',_'Ruti')
#  + variables_(5,_6,_'Science',_'A3',_'Shoshi')
#  + variables_(6,_1,_'Science',_'A3',_'Miriam')
#  + variables_(6,_1,_'Science',_'A3',_'Ruti')
#  + variables_(6,_1,_'Science',_'A3',_'Shoshi')
#  + variables_(6,_2,_'Science',_'A3',_'Miriam')
#  + variables_(6,_2,_'Science',_'A3',_'Ruti')
#  + variables_(6,_2,_'Science',_'A3',_'Shoshi')
#  + variables_(6,_3,_'Science',_'A3',_'Miriam')
#  + variables_(6,_3,_'Science',_'A3',_'Ruti')
#  + variables_(6,_3,_'Science',_'A3',_'Shoshi')
#  + variables_(6,_4,_'Science',_'A3',_'Miriam')
#  + variables_(6,_4,_'Science',_'A3',_'Ruti')
#  + variables_(6,_4,_'Science',_'A3',_'Shoshi')
#  + variables_(6,_5,_'Science',_'A3',_'Miriam')
#  + variables_(6,_5,_'Science',_'A3',_'Ruti')
#  + variables_(6,_5,_'Science',_'A3',_'Shoshi')
#  + variables_(6,_6,_'Science',_'A3',_'Miriam')
#  + variables_(6,_6,_'Science',_'A3',_'Ruti')
#  + variables_(6,_6,_'Science',_'A3',_'Shoshi') = 8
#
# _C9: variables_(1,_1,_'Bible',_'A3',_'Miriam')
#  + variables_(1,_1,_'Bible',_'A3',_'Ruti')
#  + variables_(1,_1,_'Bible',_'A3',_'Shoshi')
#  + variables_(1,_2,_'Bible',_'A3',_'Miriam')
#  + variables_(1,_2,_'Bible',_'A3',_'Ruti')
#  + variables_(1,_2,_'Bible',_'A3',_'Shoshi')
#  + variables_(1,_3,_'Bible',_'A3',_'Miriam')
#  + variables_(1,_3,_'Bible',_'A3',_'Ruti')
#  + variables_(1,_3,_'Bible',_'A3',_'Shoshi')
#  + variables_(1,_4,_'Bible',_'A3',_'Miriam')
#  + variables_(1,_4,_'Bible',_'A3',_'Ruti')
#  + variables_(1,_4,_'Bible',_'A3',_'Shoshi')
#  + variables_(1,_5,_'Bible',_'A3',_'Miriam')
#  + variables_(1,_5,_'Bible',_'A3',_'Ruti')
#  + variables_(1,_5,_'Bible',_'A3',_'Shoshi')
#  + variables_(1,_6,_'Bible',_'A3',_'Miriam')
#  + variables_(1,_6,_'Bible',_'A3',_'Ruti')
#  + variables_(1,_6,_'Bible',_'A3',_'Shoshi')
#  + variables_(2,_1,_'Bible',_'A3',_'Miriam')
#  + variables_(2,_1,_'Bible',_'A3',_'Ruti')
#  + variables_(2,_1,_'Bible',_'A3',_'Shoshi')
#  + variables_(2,_2,_'Bible',_'A3',_'Miriam')
#  + variables_(2,_2,_'Bible',_'A3',_'Ruti')
#  + variables_(2,_2,_'Bible',_'A3',_'Shoshi')
#  + variables_(2,_3,_'Bible',_'A3',_'Miriam')
#  + variables_(2,_3,_'Bible',_'A3',_'Ruti')
#  + variables_(2,_3,_'Bible',_'A3',_'Shoshi')
#  + variables_(2,_4,_'Bible',_'A3',_'Miriam')
#  + variables_(2,_4,_'Bible',_'A3',_'Ruti')
#  + variables_(2,_4,_'Bible',_'A3',_'Shoshi')
#  + variables_(2,_5,_'Bible',_'A3',_'Miriam')
#  + variables_(2,_5,_'Bible',_'A3',_'Ruti')
#  + variables_(2,_5,_'Bible',_'A3',_'Shoshi')
#  + variables_(2,_6,_'Bible',_'A3',_'Miriam')
#  + variables_(2,_6,_'Bible',_'A3',_'Ruti')
#  + variables_(2,_6,_'Bible',_'A3',_'Shoshi')
#  + variables_(3,_1,_'Bible',_'A3',_'Miriam')
#  + variables_(3,_1,_'Bible',_'A3',_'Ruti')
#  + variables_(3,_1,_'Bible',_'A3',_'Shoshi')
#  + variables_(3,_2,_'Bible',_'A3',_'Miriam')
#  + variables_(3,_2,_'Bible',_'A3',_'Ruti')
#  + variables_(3,_2,_'Bible',_'A3',_'Shoshi')
#  + variables_(3,_3,_'Bible',_'A3',_'Miriam')
#  + variables_(3,_3,_'Bible',_'A3',_'Ruti')
#  + variables_(3,_3,_'Bible',_'A3',_'Shoshi')
#  + variables_(3,_4,_'Bible',_'A3',_'Miriam')
#  + variables_(3,_4,_'Bible',_'A3',_'Ruti')
#  + variables_(3,_4,_'Bible',_'A3',_'Shoshi')
#  + variables_(3,_5,_'Bible',_'A3',_'Miriam')
#  + variables_(3,_5,_'Bible',_'A3',_'Ruti')
#  + variables_(3,_5,_'Bible',_'A3',_'Shoshi')
#  + variables_(3,_6,_'Bible',_'A3',_'Miriam')
#  + variables_(3,_6,_'Bible',_'A3',_'Ruti')
#  + variables_(3,_6,_'Bible',_'A3',_'Shoshi')
#  + variables_(4,_1,_'Bible',_'A3',_'Miriam')
#  + variables_(4,_1,_'Bible',_'A3',_'Ruti')
#  + variables_(4,_1,_'Bible',_'A3',_'Shoshi')
#  + variables_(4,_2,_'Bible',_'A3',_'Miriam')
#  + variables_(4,_2,_'Bible',_'A3',_'Ruti')
#  + variables_(4,_2,_'Bible',_'A3',_'Shoshi')
#  + variables_(4,_3,_'Bible',_'A3',_'Miriam')
#  + variables_(4,_3,_'Bible',_'A3',_'Ruti')
#  + variables_(4,_3,_'Bible',_'A3',_'Shoshi')
#  + variables_(4,_4,_'Bible',_'A3',_'Miriam')
#  + variables_(4,_4,_'Bible',_'A3',_'Ruti')
#  + variables_(4,_4,_'Bible',_'A3',_'Shoshi')
#  + variables_(4,_5,_'Bible',_'A3',_'Miriam')
#  + variables_(4,_5,_'Bible',_'A3',_'Ruti')
#  + variables_(4,_5,_'Bible',_'A3',_'Shoshi')
#  + variables_(4,_6,_'Bible',_'A3',_'Miriam')
#  + variables_(4,_6,_'Bible',_'A3',_'Ruti')
#  + variables_(4,_6,_'Bible',_'A3',_'Shoshi')
#  + variables_(5,_1,_'Bible',_'A3',_'Miriam')
#  + variables_(5,_1,_'Bible',_'A3',_'Ruti')
#  + variables_(5,_1,_'Bible',_'A3',_'Shoshi')
#  + variables_(5,_2,_'Bible',_'A3',_'Miriam')
#  + variables_(5,_2,_'Bible',_'A3',_'Ruti')
#  + variables_(5,_2,_'Bible',_'A3',_'Shoshi')
#  + variables_(5,_3,_'Bible',_'A3',_'Miriam')
#  + variables_(5,_3,_'Bible',_'A3',_'Ruti')
#  + variables_(5,_3,_'Bible',_'A3',_'Shoshi')
#  + variables_(5,_4,_'Bible',_'A3',_'Miriam')
#  + variables_(5,_4,_'Bible',_'A3',_'Ruti')
#  + variables_(5,_4,_'Bible',_'A3',_'Shoshi')
#  + variables_(5,_5,_'Bible',_'A3',_'Miriam')
#  + variables_(5,_5,_'Bible',_'A3',_'Ruti')
#  + variables_(5,_5,_'Bible',_'A3',_'Shoshi')
#  + variables_(5,_6,_'Bible',_'A3',_'Miriam')
#  + variables_(5,_6,_'Bible',_'A3',_'Ruti')
#  + variables_(5,_6,_'Bible',_'A3',_'Shoshi')
#  + variables_(6,_1,_'Bible',_'A3',_'Miriam')
#  + variables_(6,_1,_'Bible',_'A3',_'Ruti')
#  + variables_(6,_1,_'Bible',_'A3',_'Shoshi')
#  + variables_(6,_2,_'Bible',_'A3',_'Miriam')
#  + variables_(6,_2,_'Bible',_'A3',_'Ruti')
#  + variables_(6,_2,_'Bible',_'A3',_'Shoshi')
#  + variables_(6,_3,_'Bible',_'A3',_'Miriam')
#  + variables_(6,_3,_'Bible',_'A3',_'Ruti')
#  + variables_(6,_3,_'Bible',_'A3',_'Shoshi')
#  + variables_(6,_4,_'Bible',_'A3',_'Miriam')
#  + variables_(6,_4,_'Bible',_'A3',_'Ruti')
#  + variables_(6,_4,_'Bible',_'A3',_'Shoshi')
#  + variables_(6,_5,_'Bible',_'A3',_'Miriam')
#  + variables_(6,_5,_'Bible',_'A3',_'Ruti')
#  + variables_(6,_5,_'Bible',_'A3',_'Shoshi')
#  + variables_(6,_6,_'Bible',_'A3',_'Miriam')
#  + variables_(6,_6,_'Bible',_'A3',_'Ruti')
#  + variables_(6,_6,_'Bible',_'A3',_'Shoshi') = 8
#
# _C10: variables_(1,_1,_'Bible',_'A1',_'Ruti')
#  + variables_(1,_1,_'Bible',_'A2',_'Ruti')
#  + variables_(1,_1,_'Bible',_'A3',_'Ruti')
#  + variables_(1,_1,_'Math',_'A1',_'Ruti')
#  + variables_(1,_1,_'Math',_'A2',_'Ruti')
#  + variables_(1,_1,_'Math',_'A3',_'Ruti')
#  + variables_(1,_1,_'Science',_'A1',_'Ruti')
#  + variables_(1,_1,_'Science',_'A2',_'Ruti')
#  + variables_(1,_1,_'Science',_'A3',_'Ruti') <= 1
#
# _C11: variables_(1,_1,_'Bible',_'A1',_'Shoshi')
# ...
# 0 <= variables_(5,_5,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(5,_5,_'A3',_'L') <= 1 Integer
# 0 <= variables_(5,_5,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(5,_5,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_5,_'Science',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'A1',_'L') <= 1 Integer
# 0 <= variables_(5,_6,_'A1',_'Y') <= 1 Integer
# 0 <= variables_(5,_6,_'A1',_'Z') <= 1 Integer
# 0 <= variables_(5,_6,_'A2',_'L') <= 1 Integer
# 0 <= variables_(5,_6,_'A2',_'Y') <= 1 Integer
# 0 <= variables_(5,_6,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(5,_6,_'A3',_'L') <= 1 Integer
# 0 <= variables_(5,_6,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(5,_6,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(5,_6,_'Science',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'A1',_'L') <= 1 Integer
# 0 <= variables_(6,_1,_'A1',_'Y') <= 1 Integer
# 0 <= variables_(6,_1,_'A1',_'Z') <= 1 Integer
# 0 <= variables_(6,_1,_'A2',_'L') <= 1 Integer
# 0 <= variables_(6,_1,_'A2',_'Y') <= 1 Integer
# 0 <= variables_(6,_1,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(6,_1,_'A3',_'L') <= 1 Integer
# 0 <= variables_(6,_1,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(6,_1,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_1,_'Science',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'A1',_'L') <= 1 Integer
# 0 <= variables_(6,_2,_'A1',_'Y') <= 1 Integer
# 0 <= variables_(6,_2,_'A1',_'Z') <= 1 Integer
# 0 <= variables_(6,_2,_'A2',_'L') <= 1 Integer
# 0 <= variables_(6,_2,_'A2',_'Y') <= 1 Integer
# 0 <= variables_(6,_2,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(6,_2,_'A3',_'L') <= 1 Integer
# 0 <= variables_(6,_2,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(6,_2,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_2,_'Science',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'A1',_'L') <= 1 Integer
# 0 <= variables_(6,_3,_'A1',_'Y') <= 1 Integer
# 0 <= variables_(6,_3,_'A1',_'Z') <= 1 Integer
# 0 <= variables_(6,_3,_'A2',_'L') <= 1 Integer
# 0 <= variables_(6,_3,_'A2',_'Y') <= 1 Integer
# 0 <= variables_(6,_3,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(6,_3,_'A3',_'L') <= 1 Integer
# 0 <= variables_(6,_3,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(6,_3,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_3,_'Science',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'A1',_'L') <= 1 Integer
# 0 <= variables_(6,_4,_'A1',_'Y') <= 1 Integer
# 0 <= variables_(6,_4,_'A1',_'Z') <= 1 Integer
# 0 <= variables_(6,_4,_'A2',_'L') <= 1 Integer
# 0 <= variables_(6,_4,_'A2',_'Y') <= 1 Integer
# 0 <= variables_(6,_4,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(6,_4,_'A3',_'L') <= 1 Integer
# 0 <= variables_(6,_4,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(6,_4,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_4,_'Science',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'A1',_'L') <= 1 Integer
# 0 <= variables_(6,_5,_'A1',_'Y') <= 1 Integer
# 0 <= variables_(6,_5,_'A1',_'Z') <= 1 Integer
# 0 <= variables_(6,_5,_'A2',_'L') <= 1 Integer
# 0 <= variables_(6,_5,_'A2',_'Y') <= 1 Integer
# 0 <= variables_(6,_5,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(6,_5,_'A3',_'L') <= 1 Integer
# 0 <= variables_(6,_5,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(6,_5,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_5,_'Science',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'A1',_'L') <= 1 Integer
# 0 <= variables_(6,_6,_'A1',_'Y') <= 1 Integer
# 0 <= variables_(6,_6,_'A1',_'Z') <= 1 Integer
# 0 <= variables_(6,_6,_'A2',_'L') <= 1 Integer
# 0 <= variables_(6,_6,_'A2',_'Y') <= 1 Integer
# 0 <= variables_(6,_6,_'A2',_'Z') <= 1 Integer
# 0 <= variables_(6,_6,_'A3',_'L') <= 1 Integer
# 0 <= variables_(6,_6,_'A3',_'Y') <= 1 Integer
# 0 <= variables_(6,_6,_'A3',_'Z') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Bible',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Math',_'A3',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A1',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A1',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A1',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A2',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A2',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A2',_'Shoshi') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A3',_'Miriam') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A3',_'Ruti') <= 1 Integer
# 0 <= variables_(6,_6,_'Science',_'A3',_'Shoshi') <= 1 Integer

# %%
model.solve()
pulp.LpStatus[model.status]
# Out:
# 'Optimal'

# %%
for k, v in lessons_dict.items():
    if k[3] == 'A1':
        print(k, v.varValue)
# Out:
# (1, 1, 'Math', 'A1', 'Ruti') 0.0
# (1, 1, 'Math', 'A1', 'Shoshi') 0.0
# (1, 1, 'Math', 'A1', 'Miriam') 0.0
# (1, 1, 'Science', 'A1', 'Ruti') 1.0
# (1, 1, 'Science', 'A1', 'Shoshi') 0.0
# (1, 1, 'Science', 'A1', 'Miriam') 0.0
# (1, 1, 'Bible', 'A1', 'Ruti') 0.0
# (1, 1, 'Bible', 'A1', 'Shoshi') 0.0
# (1, 1, 'Bible', 'A1', 'Miriam') 0.0
# (1, 2, 'Math', 'A1', 'Ruti') 0.0
# (1, 2, 'Math', 'A1', 'Shoshi') 0.0
# (1, 2, 'Math', 'A1', 'Miriam') 0.0
# (1, 2, 'Science', 'A1', 'Ruti') 0.0
# (1, 2, 'Science', 'A1', 'Shoshi') 0.0
# (1, 2, 'Science', 'A1', 'Miriam') 0.0
# (1, 2, 'Bible', 'A1', 'Ruti') 0.0
# (1, 2, 'Bible', 'A1', 'Shoshi') 1.0
# (1, 2, 'Bible', 'A1', 'Miriam') 0.0
# (1, 3, 'Math', 'A1', 'Ruti') 0.0
# (1, 3, 'Math', 'A1', 'Shoshi') 0.0
# (1, 3, 'Math', 'A1', 'Miriam') 0.0
# (1, 3, 'Science', 'A1', 'Ruti') 0.0
# (1, 3, 'Science', 'A1', 'Shoshi') 0.0
# (1, 3, 'Science', 'A1', 'Miriam') 0.0
# (1, 3, 'Bible', 'A1', 'Ruti') 0.0
# (1, 3, 'Bible', 'A1', 'Shoshi') 0.0
# (1, 3, 'Bible', 'A1', 'Miriam') 0.0
# (1, 4, 'Math', 'A1', 'Ruti') 0.0
# (1, 4, 'Math', 'A1', 'Shoshi') 0.0
# (1, 4, 'Math', 'A1', 'Miriam') 0.0
# (1, 4, 'Science', 'A1', 'Ruti') 0.0
# (1, 4, 'Science', 'A1', 'Shoshi') 0.0
# (1, 4, 'Science', 'A1', 'Miriam') 0.0
# (1, 4, 'Bible', 'A1', 'Ruti') 0.0
# (1, 4, 'Bible', 'A1', 'Shoshi') 0.0
# (1, 4, 'Bible', 'A1', 'Miriam') 0.0
# (1, 5, 'Math', 'A1', 'Ruti') 0.0
# (1, 5, 'Math', 'A1', 'Shoshi') 0.0
# (1, 5, 'Math', 'A1', 'Miriam') 0.0
# (1, 5, 'Science', 'A1', 'Ruti') 0.0
# (1, 5, 'Science', 'A1', 'Shoshi') 0.0
# (1, 5, 'Science', 'A1', 'Miriam') 0.0
# (1, 5, 'Bible', 'A1', 'Ruti') 0.0
# (1, 5, 'Bible', 'A1', 'Shoshi') 0.0
# (1, 5, 'Bible', 'A1', 'Miriam') 0.0
# (1, 6, 'Math', 'A1', 'Ruti') 0.0
# (1, 6, 'Math', 'A1', 'Shoshi') 1.0
# (1, 6, 'Math', 'A1', 'Miriam') 0.0
# (1, 6, 'Science', 'A1', 'Ruti') 0.0
# (1, 6, 'Science', 'A1', 'Shoshi') 0.0
# (1, 6, 'Science', 'A1', 'Miriam') 0.0
# (1, 6, 'Bible', 'A1', 'Ruti') 0.0
# (1, 6, 'Bible', 'A1', 'Shoshi') 0.0
# (1, 6, 'Bible', 'A1', 'Miriam') 0.0
# (2, 1, 'Math', 'A1', 'Ruti') 0.0
# (2, 1, 'Math', 'A1', 'Shoshi') 0.0
# (2, 1, 'Math', 'A1', 'Miriam') 0.0
# (2, 1, 'Science', 'A1', 'Ruti') 0.0
# (2, 1, 'Science', 'A1', 'Shoshi') 0.0
# (2, 1, 'Science', 'A1', 'Miriam') 0.0
# (2, 1, 'Bible', 'A1', 'Ruti') 0.0
# (2, 1, 'Bible', 'A1', 'Shoshi') 0.0
# (2, 1, 'Bible', 'A1', 'Miriam') 0.0
# (2, 2, 'Math', 'A1', 'Ruti') 0.0
# (2, 2, 'Math', 'A1', 'Shoshi') 0.0
# (2, 2, 'Math', 'A1', 'Miriam') 0.0
# (2, 2, 'Science', 'A1', 'Ruti') 0.0
# (2, 2, 'Science', 'A1', 'Shoshi') 0.0
# (2, 2, 'Science', 'A1', 'Miriam') 0.0
# (2, 2, 'Bible', 'A1', 'Ruti') 0.0
# (2, 2, 'Bible', 'A1', 'Shoshi') 0.0
# (2, 2, 'Bible', 'A1', 'Miriam') 0.0
# (2, 3, 'Math', 'A1', 'Ruti') 0.0
# (2, 3, 'Math', 'A1', 'Shoshi') 0.0
# (2, 3, 'Math', 'A1', 'Miriam') 0.0
# (2, 3, 'Science', 'A1', 'Ruti') 0.0
# (2, 3, 'Science', 'A1', 'Shoshi') 0.0
# (2, 3, 'Science', 'A1', 'Miriam') 0.0
# (2, 3, 'Bible', 'A1', 'Ruti') 0.0
# (2, 3, 'Bible', 'A1', 'Shoshi') 0.0
# (2, 3, 'Bible', 'A1', 'Miriam') 0.0
# (2, 4, 'Math', 'A1', 'Ruti') 0.0
# (2, 4, 'Math', 'A1', 'Shoshi') 0.0
# (2, 4, 'Math', 'A1', 'Miriam') 0.0
# (2, 4, 'Science', 'A1', 'Ruti') 0.0
# (2, 4, 'Science', 'A1', 'Shoshi') 0.0
# (2, 4, 'Science', 'A1', 'Miriam') 0.0
# (2, 4, 'Bible', 'A1', 'Ruti') 0.0
# (2, 4, 'Bible', 'A1', 'Shoshi') 0.0
# (2, 4, 'Bible', 'A1', 'Miriam') 0.0
# (2, 5, 'Math', 'A1', 'Ruti') 0.0
# (2, 5, 'Math', 'A1', 'Shoshi') 0.0
# (2, 5, 'Math', 'A1', 'Miriam') 0.0
# (2, 5, 'Science', 'A1', 'Ruti') 0.0
# (2, 5, 'Science', 'A1', 'Shoshi') 0.0
# (2, 5, 'Science', 'A1', 'Miriam') 0.0
# (2, 5, 'Bible', 'A1', 'Ruti') 0.0
# (2, 5, 'Bible', 'A1', 'Shoshi') 0.0
# (2, 5, 'Bible', 'A1', 'Miriam') 0.0
# (2, 6, 'Math', 'A1', 'Ruti') 0.0
# (2, 6, 'Math', 'A1', 'Shoshi') 1.0
# (2, 6, 'Math', 'A1', 'Miriam') 0.0
# (2, 6, 'Science', 'A1', 'Ruti') 0.0
# (2, 6, 'Science', 'A1', 'Shoshi') 0.0
# (2, 6, 'Science', 'A1', 'Miriam') 0.0
# (2, 6, 'Bible', 'A1', 'Ruti') 0.0
# (2, 6, 'Bible', 'A1', 'Shoshi') 0.0
# (2, 6, 'Bible', 'A1', 'Miriam') 0.0
# (3, 1, 'Math', 'A1', 'Ruti') 0.0
# (3, 1, 'Math', 'A1', 'Shoshi') 0.0
# (3, 1, 'Math', 'A1', 'Miriam') 0.0
# (3, 1, 'Science', 'A1', 'Ruti') 0.0
# (3, 1, 'Science', 'A1', 'Shoshi') 0.0
# (3, 1, 'Science', 'A1', 'Miriam') 0.0
# (3, 1, 'Bible', 'A1', 'Ruti') 0.0
# (3, 1, 'Bible', 'A1', 'Shoshi') 0.0
# (3, 1, 'Bible', 'A1', 'Miriam') 0.0
# (3, 2, 'Math', 'A1', 'Ruti') 0.0
# (3, 2, 'Math', 'A1', 'Shoshi') 0.0
# (3, 2, 'Math', 'A1', 'Miriam') 0.0
# (3, 2, 'Science', 'A1', 'Ruti') 0.0
# (3, 2, 'Science', 'A1', 'Shoshi') 0.0
# (3, 2, 'Science', 'A1', 'Miriam') 0.0
# (3, 2, 'Bible', 'A1', 'Ruti') 0.0
# (3, 2, 'Bible', 'A1', 'Shoshi') 0.0
# (3, 2, 'Bible', 'A1', 'Miriam') 0.0
# (3, 3, 'Math', 'A1', 'Ruti') 0.0
# (3, 3, 'Math', 'A1', 'Shoshi') 0.0
# (3, 3, 'Math', 'A1', 'Miriam') 0.0
# (3, 3, 'Science', 'A1', 'Ruti') 0.0
# (3, 3, 'Science', 'A1', 'Shoshi') 0.0
# (3, 3, 'Science', 'A1', 'Miriam') 0.0
# (3, 3, 'Bible', 'A1', 'Ruti') 0.0
# (3, 3, 'Bible', 'A1', 'Shoshi') 0.0
# (3, 3, 'Bible', 'A1', 'Miriam') 0.0
# (3, 4, 'Math', 'A1', 'Ruti') 0.0
# (3, 4, 'Math', 'A1', 'Shoshi') 0.0
# (3, 4, 'Math', 'A1', 'Miriam') 0.0
# (3, 4, 'Science', 'A1', 'Ruti') 0.0
# (3, 4, 'Science', 'A1', 'Shoshi') 0.0
# (3, 4, 'Science', 'A1', 'Miriam') 0.0
# (3, 4, 'Bible', 'A1', 'Ruti') 0.0
# (3, 4, 'Bible', 'A1', 'Shoshi') 0.0
# (3, 4, 'Bible', 'A1', 'Miriam') 0.0
# (3, 5, 'Math', 'A1', 'Ruti') 0.0
# (3, 5, 'Math', 'A1', 'Shoshi') 1.0
# (3, 5, 'Math', 'A1', 'Miriam') 0.0
# (3, 5, 'Science', 'A1', 'Ruti') 0.0
# (3, 5, 'Science', 'A1', 'Shoshi') 0.0
# (3, 5, 'Science', 'A1', 'Miriam') 0.0
# (3, 5, 'Bible', 'A1', 'Ruti') 0.0
# (3, 5, 'Bible', 'A1', 'Shoshi') 0.0
# (3, 5, 'Bible', 'A1', 'Miriam') 0.0
# (3, 6, 'Math', 'A1', 'Ruti') 0.0
# (3, 6, 'Math', 'A1', 'Shoshi') 0.0
# (3, 6, 'Math', 'A1', 'Miriam') 0.0
# (3, 6, 'Science', 'A1', 'Ruti') 0.0
# (3, 6, 'Science', 'A1', 'Shoshi') 0.0
# (3, 6, 'Science', 'A1', 'Miriam') 0.0
# (3, 6, 'Bible', 'A1', 'Ruti') 0.0
# (3, 6, 'Bible', 'A1', 'Shoshi') 1.0
# (3, 6, 'Bible', 'A1', 'Miriam') 0.0
# (4, 1, 'Math', 'A1', 'Ruti') 0.0
# (4, 1, 'Math', 'A1', 'Shoshi') 1.0
# (4, 1, 'Math', 'A1', 'Miriam') 0.0
# (4, 1, 'Science', 'A1', 'Ruti') 0.0
# (4, 1, 'Science', 'A1', 'Shoshi') 0.0
# (4, 1, 'Science', 'A1', 'Miriam') 0.0
# (4, 1, 'Bible', 'A1', 'Ruti') 0.0
# (4, 1, 'Bible', 'A1', 'Shoshi') 0.0
# (4, 1, 'Bible', 'A1', 'Miriam') 0.0
# (4, 2, 'Math', 'A1', 'Ruti') 0.0
# (4, 2, 'Math', 'A1', 'Shoshi') 0.0
# (4, 2, 'Math', 'A1', 'Miriam') 0.0
# (4, 2, 'Science', 'A1', 'Ruti') 1.0
# (4, 2, 'Science', 'A1', 'Shoshi') 0.0
# (4, 2, 'Science', 'A1', 'Miriam') 0.0
# (4, 2, 'Bible', 'A1', 'Ruti') 0.0
# (4, 2, 'Bible', 'A1', 'Shoshi') 0.0
# (4, 2, 'Bible', 'A1', 'Miriam') 0.0
# (4, 3, 'Math', 'A1', 'Ruti') 0.0
# (4, 3, 'Math', 'A1', 'Shoshi') 0.0
# (4, 3, 'Math', 'A1', 'Miriam') 0.0
# (4, 3, 'Science', 'A1', 'Ruti') 0.0
# (4, 3, 'Science', 'A1', 'Shoshi') 0.0
# (4, 3, 'Science', 'A1', 'Miriam') 0.0
# (4, 3, 'Bible', 'A1', 'Ruti') 0.0
# (4, 3, 'Bible', 'A1', 'Shoshi') 1.0
# (4, 3, 'Bible', 'A1', 'Miriam') 0.0
# (4, 4, 'Math', 'A1', 'Ruti') 0.0
# (4, 4, 'Math', 'A1', 'Shoshi') 1.0
# (4, 4, 'Math', 'A1', 'Miriam') 0.0
# (4, 4, 'Science', 'A1', 'Ruti') 0.0
# (4, 4, 'Science', 'A1', 'Shoshi') 0.0
# (4, 4, 'Science', 'A1', 'Miriam') 0.0
# (4, 4, 'Bible', 'A1', 'Ruti') 0.0
# (4, 4, 'Bible', 'A1', 'Shoshi') 0.0
# (4, 4, 'Bible', 'A1', 'Miriam') 0.0
# (4, 5, 'Math', 'A1', 'Ruti') 0.0
# (4, 5, 'Math', 'A1', 'Shoshi') 0.0
# (4, 5, 'Math', 'A1', 'Miriam') 0.0
# (4, 5, 'Science', 'A1', 'Ruti') 1.0
# (4, 5, 'Science', 'A1', 'Shoshi') 0.0
# (4, 5, 'Science', 'A1', 'Miriam') 0.0
# (4, 5, 'Bible', 'A1', 'Ruti') 0.0
# (4, 5, 'Bible', 'A1', 'Shoshi') 0.0
# (4, 5, 'Bible', 'A1', 'Miriam') 0.0
# (4, 6, 'Math', 'A1', 'Ruti') 0.0
# (4, 6, 'Math', 'A1', 'Shoshi') 0.0
# (4, 6, 'Math', 'A1', 'Miriam') 0.0
# (4, 6, 'Science', 'A1', 'Ruti') 0.0
# (4, 6, 'Science', 'A1', 'Shoshi') 0.0
# (4, 6, 'Science', 'A1', 'Miriam') 0.0
# (4, 6, 'Bible', 'A1', 'Ruti') 0.0
# (4, 6, 'Bible', 'A1', 'Shoshi') 0.0
# (4, 6, 'Bible', 'A1', 'Miriam') 1.0
# (5, 1, 'Math', 'A1', 'Ruti') 0.0
# (5, 1, 'Math', 'A1', 'Shoshi') 0.0
# (5, 1, 'Math', 'A1', 'Miriam') 0.0
# (5, 1, 'Science', 'A1', 'Ruti') 0.0
# (5, 1, 'Science', 'A1', 'Shoshi') 0.0
# (5, 1, 'Science', 'A1', 'Miriam') 0.0
# (5, 1, 'Bible', 'A1', 'Ruti') 0.0
# (5, 1, 'Bible', 'A1', 'Shoshi') 1.0
# (5, 1, 'Bible', 'A1', 'Miriam') 0.0
# (5, 2, 'Math', 'A1', 'Ruti') 0.0
# (5, 2, 'Math', 'A1', 'Shoshi') 0.0
# (5, 2, 'Math', 'A1', 'Miriam') 0.0
# (5, 2, 'Science', 'A1', 'Ruti') 1.0
# (5, 2, 'Science', 'A1', 'Shoshi') 0.0
# (5, 2, 'Science', 'A1', 'Miriam') 0.0
# (5, 2, 'Bible', 'A1', 'Ruti') 0.0
# (5, 2, 'Bible', 'A1', 'Shoshi') 0.0
# (5, 2, 'Bible', 'A1', 'Miriam') 0.0
# (5, 3, 'Math', 'A1', 'Ruti') 0.0
# (5, 3, 'Math', 'A1', 'Shoshi') 0.0
# (5, 3, 'Math', 'A1', 'Miriam') 0.0
# (5, 3, 'Science', 'A1', 'Ruti') 1.0
# (5, 3, 'Science', 'A1', 'Shoshi') 0.0
# (5, 3, 'Science', 'A1', 'Miriam') 0.0
# (5, 3, 'Bible', 'A1', 'Ruti') 0.0
# (5, 3, 'Bible', 'A1', 'Shoshi') 0.0
# (5, 3, 'Bible', 'A1', 'Miriam') 0.0
# (5, 4, 'Math', 'A1', 'Ruti') 1.0
# (5, 4, 'Math', 'A1', 'Shoshi') 0.0
# (5, 4, 'Math', 'A1', 'Miriam') 0.0
# (5, 4, 'Science', 'A1', 'Ruti') 0.0
# (5, 4, 'Science', 'A1', 'Shoshi') 0.0
# (5, 4, 'Science', 'A1', 'Miriam') 0.0
# (5, 4, 'Bible', 'A1', 'Ruti') 0.0
# (5, 4, 'Bible', 'A1', 'Shoshi') 0.0
# (5, 4, 'Bible', 'A1', 'Miriam') 0.0
# (5, 5, 'Math', 'A1', 'Ruti') 0.0
# (5, 5, 'Math', 'A1', 'Shoshi') 0.0
# (5, 5, 'Math', 'A1', 'Miriam') 0.0
# (5, 5, 'Science', 'A1', 'Ruti') 0.0
# (5, 5, 'Science', 'A1', 'Shoshi') 0.0
# (5, 5, 'Science', 'A1', 'Miriam') 0.0
# (5, 5, 'Bible', 'A1', 'Ruti') 0.0
# (5, 5, 'Bible', 'A1', 'Shoshi') 0.0
# (5, 5, 'Bible', 'A1', 'Miriam') 1.0
# (5, 6, 'Math', 'A1', 'Ruti') 0.0
# (5, 6, 'Math', 'A1', 'Shoshi') 1.0
# (5, 6, 'Math', 'A1', 'Miriam') 0.0
# (5, 6, 'Science', 'A1', 'Ruti') 0.0
# (5, 6, 'Science', 'A1', 'Shoshi') 0.0
# (5, 6, 'Science', 'A1', 'Miriam') 0.0
# (5, 6, 'Bible', 'A1', 'Ruti') 0.0
# (5, 6, 'Bible', 'A1', 'Shoshi') 0.0
# (5, 6, 'Bible', 'A1', 'Miriam') 0.0
# (6, 1, 'Math', 'A1', 'Ruti') 0.0
# (6, 1, 'Math', 'A1', 'Shoshi') 0.0
# (6, 1, 'Math', 'A1', 'Miriam') 0.0
# (6, 1, 'Science', 'A1', 'Ruti') 1.0
# (6, 1, 'Science', 'A1', 'Shoshi') 0.0
# (6, 1, 'Science', 'A1', 'Miriam') 0.0
# (6, 1, 'Bible', 'A1', 'Ruti') 0.0
# (6, 1, 'Bible', 'A1', 'Shoshi') 0.0
# (6, 1, 'Bible', 'A1', 'Miriam') 0.0
# (6, 2, 'Math', 'A1', 'Ruti') 0.0
# (6, 2, 'Math', 'A1', 'Shoshi') 0.0
# (6, 2, 'Math', 'A1', 'Miriam') 0.0
# (6, 2, 'Science', 'A1', 'Ruti') 0.0
# (6, 2, 'Science', 'A1', 'Shoshi') 0.0
# (6, 2, 'Science', 'A1', 'Miriam') 0.0
# (6, 2, 'Bible', 'A1', 'Ruti') 0.0
# (6, 2, 'Bible', 'A1', 'Shoshi') 0.0
# (6, 2, 'Bible', 'A1', 'Miriam') 1.0
# (6, 3, 'Math', 'A1', 'Ruti') 0.0
# (6, 3, 'Math', 'A1', 'Shoshi') 1.0
# (6, 3, 'Math', 'A1', 'Miriam') 0.0
# (6, 3, 'Science', 'A1', 'Ruti') 0.0
# (6, 3, 'Science', 'A1', 'Shoshi') 0.0
# (6, 3, 'Science', 'A1', 'Miriam') 0.0
# (6, 3, 'Bible', 'A1', 'Ruti') 0.0
# (6, 3, 'Bible', 'A1', 'Shoshi') 0.0
# (6, 3, 'Bible', 'A1', 'Miriam') 0.0
# (6, 4, 'Math', 'A1', 'Ruti') 0.0
# (6, 4, 'Math', 'A1', 'Shoshi') 0.0
# (6, 4, 'Math', 'A1', 'Miriam') 0.0
# (6, 4, 'Science', 'A1', 'Ruti') 0.0
# (6, 4, 'Science', 'A1', 'Shoshi') 0.0
# (6, 4, 'Science', 'A1', 'Miriam') 0.0
# (6, 4, 'Bible', 'A1', 'Ruti') 0.0
# (6, 4, 'Bible', 'A1', 'Shoshi') 1.0
# (6, 4, 'Bible', 'A1', 'Miriam') 0.0
# (6, 5, 'Math', 'A1', 'Ruti') 0.0
# (6, 5, 'Math', 'A1', 'Shoshi') 0.0
# (6, 5, 'Math', 'A1', 'Miriam') 0.0
# (6, 5, 'Science', 'A1', 'Ruti') 1.0
# (6, 5, 'Science', 'A1', 'Shoshi') 0.0
# (6, 5, 'Science', 'A1', 'Miriam') 0.0
# (6, 5, 'Bible', 'A1', 'Ruti') 0.0
# (6, 5, 'Bible', 'A1', 'Shoshi') 0.0
# (6, 5, 'Bible', 'A1', 'Miriam') 0.0
# (6, 6, 'Math', 'A1', 'Ruti') 0.0
# (6, 6, 'Math', 'A1', 'Shoshi') 0.0
# (6, 6, 'Math', 'A1', 'Miriam') 0.0
# (6, 6, 'Science', 'A1', 'Ruti') 1.0
# (6, 6, 'Science', 'A1', 'Shoshi') 0.0
# (6, 6, 'Science', 'A1', 'Miriam') 0.0
# (6, 6, 'Bible', 'A1', 'Ruti') 0.0
# (6, 6, 'Bible', 'A1', 'Shoshi') 0.0
# (6, 6, 'Bible', 'A1', 'Miriam') 0.0

# %% [markdown]
# # END

# %%
# Iterables
days = lessons_data['Day'].drop_duplicates()
hours = lessons_data['Hour'].drop_duplicates()
lessons = lessons_data['Lesson'].drop_duplicates()

# %%
# Each lesson has two hours
for lesson in lessons:
    expr = pulp.LpAffineExpression()
    for day in days:
        for hour in hours:
            expr += lessons_status[day, hour, lesson]
    const = (expr == 2)
    model += const

# %%
# No more than 6 hours in a day
for day in days:
    expr = pulp.LpAffineExpression()
    for lesson in lessons:
        for hour in hours:
            expr += lessons_status[day, hour, lesson]
    const = (expr <= 6)
    model += const

# %%
# See the model
model
# Out:
# Minimize amount of lessons:
# MINIMIZE
# 1*lessons_(1,_1,_'Art') + 1*lessons_(1,_1,_'Bible') + 1*lessons_(1,_1,_'Education') + 1*lessons_(1,_1,_'Hebrew') + 1*lessons_(1,_1,_'Math') + 1*lessons_(1,_1,_'Music') + 1*lessons_(1,_1,_'Science') + 1*lessons_(1,_1,_'Sport') + 1*lessons_(1,_2,_'Art') + 1*lessons_(1,_2,_'Bible') + 1*lessons_(1,_2,_'Education') + 1*lessons_(1,_2,_'Hebrew') + 1*lessons_(1,_2,_'Math') + 1*lessons_(1,_2,_'Music') + 1*lessons_(1,_2,_'Science') + 1*lessons_(1,_2,_'Sport') + 1*lessons_(1,_3,_'Art') + 1*lessons_(1,_3,_'Bible') + 1*lessons_(1,_3,_'Education') + 1*lessons_(1,_3,_'Hebrew') + 1*lessons_(1,_3,_'Math') + 1*lessons_(1,_3,_'Music') + 1*lessons_(1,_3,_'Science') + 1*lessons_(1,_3,_'Sport') + 1*lessons_(1,_4,_'Art') + 1*lessons_(1,_4,_'Bible') + 1*lessons_(1,_4,_'Education') + 1*lessons_(1,_4,_'Hebrew') + 1*lessons_(1,_4,_'Math') + 1*lessons_(1,_4,_'Music') + 1*lessons_(1,_4,_'Science') + 1*lessons_(1,_4,_'Sport') + 1*lessons_(1,_5,_'Art') + 1*lessons_(1,_5,_'Bible') + 1*lessons_(1,_5,_'Education') + 1*lessons_(1,_5,_'Hebrew') + 1*lessons_(1,_5,_'Math') + 1*lessons_(1,_5,_'Music') + 1*lessons_(1,_5,_'Science') + 1*lessons_(1,_5,_'Sport') + 1*lessons_(1,_6,_'Art') + 1*lessons_(1,_6,_'Bible') + 1*lessons_(1,_6,_'Education') + 1*lessons_(1,_6,_'Hebrew') + 1*lessons_(1,_6,_'Math') + 1*lessons_(1,_6,_'Music') + 1*lessons_(1,_6,_'Science') + 1*lessons_(1,_6,_'Sport') + 1*lessons_(1,_7,_'Art') + 1*lessons_(1,_7,_'Bible') + 1*lessons_(1,_7,_'Education') + 1*lessons_(1,_7,_'Hebrew') + 1*lessons_(1,_7,_'Math') + 1*lessons_(1,_7,_'Music') + 1*lessons_(1,_7,_'Science') + 1*lessons_(1,_7,_'Sport') + 1*lessons_(1,_8,_'Art') + 1*lessons_(1,_8,_'Bible') + 1*lessons_(1,_8,_'Education') + 1*lessons_(1,_8,_'Hebrew') + 1*lessons_(1,_8,_'Math') + 1*lessons_(1,_8,_'Music') + 1*lessons_(1,_8,_'Science') + 1*lessons_(1,_8,_'Sport') + 1*lessons_(2,_1,_'Art') + 1*lessons_(2,_1,_'Bible') + 1*lessons_(2,_1,_'Education') + 1*lessons_(2,_1,_'Hebrew') + 1*lessons_(2,_1,_'Math') + 1*lessons_(2,_1,_'Music') + 1*lessons_(2,_1,_'Science') + 1*lessons_(2,_1,_'Sport') + 1*lessons_(2,_2,_'Art') + 1*lessons_(2,_2,_'Bible') + 1*lessons_(2,_2,_'Education') + 1*lessons_(2,_2,_'Hebrew') + 1*lessons_(2,_2,_'Math') + 1*lessons_(2,_2,_'Music') + 1*lessons_(2,_2,_'Science') + 1*lessons_(2,_2,_'Sport') + 1*lessons_(2,_3,_'Art') + 1*lessons_(2,_3,_'Bible') + 1*lessons_(2,_3,_'Education') + 1*lessons_(2,_3,_'Hebrew') + 1*lessons_(2,_3,_'Math') + 1*lessons_(2,_3,_'Music') + 1*lessons_(2,_3,_'Science') + 1*lessons_(2,_3,_'Sport') + 1*lessons_(2,_4,_'Art') + 1*lessons_(2,_4,_'Bible') + 1*lessons_(2,_4,_'Education') + 1*lessons_(2,_4,_'Hebrew') + 1*lessons_(2,_4,_'Math') + 1*lessons_(2,_4,_'Music') + 1*lessons_(2,_4,_'Science') + 1*lessons_(2,_4,_'Sport') + 1*lessons_(2,_5,_'Art') + 1*lessons_(2,_5,_'Bible') + 1*lessons_(2,_5,_'Education') + 1*lessons_(2,_5,_'Hebrew') + 1*lessons_(2,_5,_'Math') + 1*lessons_(2,_5,_'Music') + 1*lessons_(2,_5,_'Science') + 1*lessons_(2,_5,_'Sport') + 1*lessons_(2,_6,_'Art') + 1*lessons_(2,_6,_'Bible') + 1*lessons_(2,_6,_'Education') + 1*lessons_(2,_6,_'Hebrew') + 1*lessons_(2,_6,_'Math') + 1*lessons_(2,_6,_'Music') + 1*lessons_(2,_6,_'Science') + 1*lessons_(2,_6,_'Sport') + 1*lessons_(2,_7,_'Art') + 1*lessons_(2,_7,_'Bible') + 1*lessons_(2,_7,_'Education') + 1*lessons_(2,_7,_'Hebrew') + 1*lessons_(2,_7,_'Math') + 1*lessons_(2,_7,_'Music') + 1*lessons_(2,_7,_'Science') + 1*lessons_(2,_7,_'Sport') + 1*lessons_(2,_8,_'Art') + 1*lessons_(2,_8,_'Bible') + 1*lessons_(2,_8,_'Education') + 1*lessons_(2,_8,_'Hebrew') + 1*lessons_(2,_8,_'Math') + 1*lessons_(2,_8,_'Music') + 1*lessons_(2,_8,_'Science') + 1*lessons_(2,_8,_'Sport') + 1*lessons_(3,_1,_'Art') + 1*lessons_(3,_1,_'Bible') + 1*lessons_(3,_1,_'Education') + 1*lessons_(3,_1,_'Hebrew') + 1*lessons_(3,_1,_'Math') + 1*lessons_(3,_1,_'Music') + 1*lessons_(3,_1,_'Science') + 1*lessons_(3,_1,_'Sport') + 1*lessons_(3,_2,_'Art') + 1*lessons_(3,_2,_'Bible') + 1*lessons_(3,_2,_'Education') + 1*lessons_(3,_2,_'Hebrew') + 1*lessons ...
# SUBJECT TO
# _C1: lessons_(1,_1,_'Math') + lessons_(1,_2,_'Math') + lessons_(1,_3,_'Math')
#  + lessons_(1,_4,_'Math') + lessons_(1,_5,_'Math') + lessons_(1,_6,_'Math')
#  + lessons_(1,_7,_'Math') + lessons_(1,_8,_'Math') + lessons_(2,_1,_'Math')
#  + lessons_(2,_2,_'Math') + lessons_(2,_3,_'Math') + lessons_(2,_4,_'Math')
#  + lessons_(2,_5,_'Math') + lessons_(2,_6,_'Math') + lessons_(2,_7,_'Math')
#  + lessons_(2,_8,_'Math') + lessons_(3,_1,_'Math') + lessons_(3,_2,_'Math')
#  + lessons_(3,_3,_'Math') + lessons_(3,_4,_'Math') + lessons_(3,_5,_'Math')
#  + lessons_(3,_6,_'Math') + lessons_(3,_7,_'Math') + lessons_(3,_8,_'Math')
#  + lessons_(4,_1,_'Math') + lessons_(4,_2,_'Math') + lessons_(4,_3,_'Math')
#  + lessons_(4,_4,_'Math') + lessons_(4,_5,_'Math') + lessons_(4,_6,_'Math')
#  + lessons_(4,_7,_'Math') + lessons_(4,_8,_'Math') + lessons_(5,_1,_'Math')
#  + lessons_(5,_2,_'Math') + lessons_(5,_3,_'Math') + lessons_(5,_4,_'Math')
#  + lessons_(5,_5,_'Math') + lessons_(5,_6,_'Math') + lessons_(5,_7,_'Math')
#  + lessons_(5,_8,_'Math') + lessons_(6,_1,_'Math') + lessons_(6,_2,_'Math')
#  + lessons_(6,_3,_'Math') + lessons_(6,_4,_'Math') + lessons_(6,_5,_'Math')
#  + lessons_(6,_6,_'Math') + lessons_(6,_7,_'Math') + lessons_(6,_8,_'Math')
#  = 2
#
# _C2: lessons_(1,_1,_'Science') + lessons_(1,_2,_'Science')
#  + lessons_(1,_3,_'Science') + lessons_(1,_4,_'Science')
#  + lessons_(1,_5,_'Science') + lessons_(1,_6,_'Science')
#  + lessons_(1,_7,_'Science') + lessons_(1,_8,_'Science')
#  + lessons_(2,_1,_'Science') + lessons_(2,_2,_'Science')
#  + lessons_(2,_3,_'Science') + lessons_(2,_4,_'Science')
#  + lessons_(2,_5,_'Science') + lessons_(2,_6,_'Science')
#  + lessons_(2,_7,_'Science') + lessons_(2,_8,_'Science')
#  + lessons_(3,_1,_'Science') + lessons_(3,_2,_'Science')
#  + lessons_(3,_3,_'Science') + lessons_(3,_4,_'Science')
#  + lessons_(3,_5,_'Science') + lessons_(3,_6,_'Science')
#  + lessons_(3,_7,_'Science') + lessons_(3,_8,_'Science')
#  + lessons_(4,_1,_'Science') + lessons_(4,_2,_'Science')
#  + lessons_(4,_3,_'Science') + lessons_(4,_4,_'Science')
#  + lessons_(4,_5,_'Science') + lessons_(4,_6,_'Science')
#  + lessons_(4,_7,_'Science') + lessons_(4,_8,_'Science')
#  + lessons_(5,_1,_'Science') + lessons_(5,_2,_'Science')
#  + lessons_(5,_3,_'Science') + lessons_(5,_4,_'Science')
#  + lessons_(5,_5,_'Science') + lessons_(5,_6,_'Science')
#  + lessons_(5,_7,_'Science') + lessons_(5,_8,_'Science')
#  + lessons_(6,_1,_'Science') + lessons_(6,_2,_'Science')
#  + lessons_(6,_3,_'Science') + lessons_(6,_4,_'Science')
#  + lessons_(6,_5,_'Science') + lessons_(6,_6,_'Science')
#  + lessons_(6,_7,_'Science') + lessons_(6,_8,_'Science') = 2
#
# _C3: lessons_(1,_1,_'Hebrew') + lessons_(1,_2,_'Hebrew')
#  + lessons_(1,_3,_'Hebrew') + lessons_(1,_4,_'Hebrew')
#  + lessons_(1,_5,_'Hebrew') + lessons_(1,_6,_'Hebrew')
#  + lessons_(1,_7,_'Hebrew') + lessons_(1,_8,_'Hebrew')
#  + lessons_(2,_1,_'Hebrew') + lessons_(2,_2,_'Hebrew')
#  + lessons_(2,_3,_'Hebrew') + lessons_(2,_4,_'Hebrew')
#  + lessons_(2,_5,_'Hebrew') + lessons_(2,_6,_'Hebrew')
#  + lessons_(2,_7,_'Hebrew') + lessons_(2,_8,_'Hebrew')
#  + lessons_(3,_1,_'Hebrew') + lessons_(3,_2,_'Hebrew')
#  + lessons_(3,_3,_'Hebrew') + lessons_(3,_4,_'Hebrew')
#  + lessons_(3,_5,_'Hebrew') + lessons_(3,_6,_'Hebrew')
#  + lessons_(3,_7,_'Hebrew') + lessons_(3,_8,_'Hebrew')
#  + lessons_(4,_1,_'Hebrew') + lessons_(4,_2,_'Hebrew')
#  + lessons_(4,_3,_'Hebrew') + lessons_(4,_4,_'Hebrew')
#  + lessons_(4,_5,_'Hebrew') + lessons_(4,_6,_'Hebrew')
#  + lessons_(4,_7,_'Hebrew') + lessons_(4,_8,_'Hebrew')
#  + lessons_(5,_1,_'Hebrew') + lessons_(5,_2,_'Hebrew')
#  + lessons_(5,_3,_'Hebrew') + lessons_(5,_4,_'Hebrew')
#  + lessons_(5,_5,_'Hebrew') + lessons_(5,_6,_'Hebrew')
#  + lessons_(5,_7,_'Hebrew') + lessons_(5,_8,_'Hebrew')
#  + lessons_(6,_1,_'Hebrew') + lessons_(6,_2,_'Hebrew')
#  + lessons_(6,_3,_'Hebrew') + lessons_(6,_4,_'Hebrew')
#  + lessons_(6,_5,_'Hebrew') + lessons_(6,_6,_'Hebrew')
#  + lessons_(6,_7,_'Hebrew') + lessons_(6,_8,_'Hebrew') = 2
#
# _C4: lessons_(1,_1,_'Bible') + lessons_(1,_2,_'Bible')
#  + lessons_(1,_3,_'Bible') + lessons_(1,_4,_'Bible') + lessons_(1,_5,_'Bible')
#  + lessons_(1,_6,_'Bible') + lessons_(1,_7,_'Bible') + lessons_(1,_8,_'Bible')
#  + lessons_(2,_1,_'Bible') + lessons_(2,_2,_'Bible') + lessons_(2,_3,_'Bible')
#  + lessons_(2,_4,_'Bible') + lessons_(2,_5,_'Bible') + lessons_(2,_6,_'Bible')
#  + lessons_(2,_7,_'Bible') + lessons_(2,_8,_'Bible') + lessons_(3,_1,_'Bible')
#  + lessons_(3,_2,_'Bible') + lessons_(3,_3,_'Bible') + lessons_(3,_4,_'Bible')
#  + lessons_(3,_5,_'Bible') + lessons_(3,_6,_'Bible') + lessons_(3,_7,_'Bible')
#  + lessons_(3,_8,_'Bible') + lessons_(4,_1,_'Bible') + lessons_(4,_2,_'Bible')
#  + lessons_(4,_3,_'Bible') + lessons_(4,_4,_'Bible') + lessons_(4,_5,_'Bible')
#  + lessons_(4,_6,_'Bible') + lessons_(4,_7,_'Bible') + lessons_(4,_8,_'Bible')
#  + lessons_(5,_1,_'Bible') + lessons_(5,_2,_'Bible') + lessons_(5,_3,_'Bible')
#  + lessons_(5,_4,_'Bible') + lessons_(5,_5,_'Bible') + lessons_(5,_6,_'Bible')
#  + lessons_(5,_7,_'Bible') + lessons_(5,_8,_'Bible') + lessons_(6,_1,_'Bible')
#  + lessons_(6,_2,_'Bible') + lessons_(6,_3,_'Bible') + lessons_(6,_4,_'Bible')
#  + lessons_(6,_5,_'Bible') + lessons_(6,_6,_'Bible') + lessons_(6,_7,_'Bible')
#  + lessons_(6,_8,_'Bible') = 2
#
# _C5: lessons_(1,_1,_'Music') + lessons_(1,_2,_'Music')
#  + lessons_(1,_3,_'Music') + lessons_(1,_4,_'Music') + lessons_(1,_5,_'Music')
#  + lessons_(1,_6,_'Music') + lessons_(1,_7,_'Music') + lessons_(1,_8,_'Music')
#  + lessons_(2,_1,_'Music') + lessons_(2,_2,_'Music') + lessons_(2,_3,_'Music')
#  + lessons_(2,_4,_'Music') + lessons_(2,_5,_'Music') + lessons_(2,_6,_'Music')
#  + lessons_(2,_7,_'Music') + lessons_(2,_8,_'Music') + lessons_(3,_1,_'Music')
#  + lessons_(3,_2,_'Music') + lessons_(3,_3,_'Music') + lessons_(3,_4,_'Music')
#  + lessons_(3,_5,_'Music') + lessons_(3,_6,_'Music') + lessons_(3,_7,_'Music')
#  + lessons_(3,_8,_'Music') + lessons_(4,_1,_'Music') + lessons_(4,_2,_'Music')
#  + lessons_(4,_3,_'Music') + lessons_(4,_4,_'Music') + lessons_(4,_5,_'Music')
#  + lessons_(4,_6,_'Music') + lessons_(4,_7,_'Music') + lessons_(4,_8,_'Music')
#  + lessons_(5,_1,_'Music') + lessons_(5,_2,_'Music') + lessons_(5,_3,_'Music')
#  + lessons_(5,_4,_'Music') + lessons_(5,_5,_'Music') + lessons_(5,_6,_'Music')
#  + lessons_(5,_7,_'Music') + lessons_(5,_8,_'Music') + lessons_(6,_1,_'Music')
#  + lessons_(6,_2,_'Music') + lessons_(6,_3,_'Music') + lessons_(6,_4,_'Music')
#  + lessons_(6,_5,_'Music') + lessons_(6,_6,_'Music') + lessons_(6,_7,_'Music')
#  + lessons_(6,_8,_'Music') = 2
#
# _C6: lessons_(1,_1,_'Education') + lessons_(1,_2,_'Education')
#  + lessons_(1,_3,_'Education') + lessons_(1,_4,_'Education')
#  + lessons_(1,_5,_'Education') + lessons_(1,_6,_'Education')
#  + lessons_(1,_7,_'Education') + lessons_(1,_8,_'Education')
#  + lessons_(2,_1,_'Education') + lessons_(2,_2,_'Education')
#  + lessons_(2,_3,_'Education') + lessons_(2,_4,_'Education')
#  + lessons_(2,_5,_'Education') + lessons_(2,_6,_'Education')
#  + lessons_(2,_7,_'Education') + lessons_(2,_8,_'Education')
#  + lessons_(3,_1,_'Education') + lessons_(3,_2,_'Education')
#  + lessons_(3,_3,_'Education') + lessons_(3,_4,_'Education')
#  + lessons_(3,_5,_'Education') + lessons_(3,_6,_'Education')
#  + lessons_(3,_7,_'Education') + lessons_(3,_8,_'Education')
#  + lessons_(4,_1,_'Education') + lessons_(4,_2,_'Education')
#  + lessons_(4,_3,_'Education') + lessons_(4,_4,_'Education')
#  + lessons_(4,_5,_'Education') + lessons_(4,_6,_'Education')
#  + lessons_(4,_7,_'Education') + lessons_(4,_8,_'Education')
#  + lessons_(5,_1,_'Education') + lessons_(5,_2,_'Education')
#  + lessons_(5,_3,_'Education') + lessons_(5,_4,_'Education')
#  + lessons_(5,_5,_'Education') + lessons_(5,_6,_'Education')
#  + lessons_(5,_7,_'Education') + lessons_(5,_8,_'Education')
#  + lessons_(6,_1,_'Education') + lessons_(6,_2,_'Education')
#  + lessons_(6,_3,_'Education') + lessons_(6,_4,_'Education')
#  + lessons_(6,_5,_'Education') + lessons_(6,_6,_'Education')
#  + lessons_(6,_7,_'Education') + lessons_(6,_8,_'Education') = 2
#
# _C7: lessons_(1,_1,_'Sport') + lessons_(1,_2,_'Sport')
#  + lessons_(1,_3,_'Sport') + lessons_(1,_4,_'Sport') + lessons_(1,_5,_'Sport')
#  + lessons_(1,_6,_'Sport') + lessons_(1,_7,_'Sport') + lessons_(1,_8,_'Sport')
#  + lessons_(2,_1,_'Sport') + lessons_(2,_2,_'Sport') + lessons_(2,_3,_'Sport')
#  + lessons_(2,_4,_'Sport') + lessons_(2,_5,_'Sport') + lessons_(2,_6,_'Sport')
#  + lessons_(2,_7,_'Sport') + lessons_(2,_8,_'Sport') + lessons_(3,_1,_'Sport')
#  + lessons_(3,_2,_'Sport') + lessons_(3,_3,_'Sport') + lessons_(3,_4,_'Sport')
#  + lessons_(3,_5,_'Sport') + lessons_(3,_6,_'Sport') + lessons_(3,_7,_'Sport')
#  + lessons_(3,_8,_'Sport') + lessons_(4,_1,_'Sport') + lessons_(4,_2,_'Sport')
#  + lessons_(4,_3,_'Sport') + lessons_(4,_4,_'Sport') + lessons_(4,_5,_'Sport')
#  + lessons_(4,_6,_'Sport') + lessons_(4,_7,_'Sport') + lessons_(4,_8,_'Sport')
#  + lessons_(5,_1,_'Sport') + lessons_(5,_2,_'Sport') + lessons_(5,_3,_'Sport')
#  + lessons_(5,_4,_'Sport') + lessons_(5,_5,_'Sport') + lessons_(5,_6,_'Sport')
#  + lessons_(5,_7,_'Sport') + lessons_(5,_8,_'Sport') + lessons_(6,_1,_'Sport')
#  + lessons_(6,_2,_'Sport') + lessons_(6,_3,_'Sport') + lessons_(6,_4,_'Sport')
#  + lessons_(6,_5,_'Sport') + lessons_(6,_6,_'Sport') + lessons_(6,_7,_'Sport')
#  + lessons_(6,_8,_'Sport') = 2
#
# _C8: lessons_(1,_1,_'Art') + lessons_(1,_2,_'Art') + lessons_(1,_3,_'Art')
#  + lessons_(1,_4,_'Art') + lessons_(1,_5,_'Art') + lessons_(1,_6,_'Art')
#  + lessons_(1,_7,_'Art') + lessons_(1,_8,_'Art') + lessons_(2,_1,_'Art')
#  + lessons_(2,_2,_'Art') + lessons_(2,_3,_'Art') + lessons_(2,_4,_'Art')
#  + lessons_(2,_5,_'Art') + lessons_(2,_6,_'Art') + lessons_(2,_7,_'Art')
#  + lessons_(2,_8,_'Art') + lessons_(3,_1,_'Art') + lessons_(3,_2,_'Art')
#  + lessons_(3,_3,_'Art') + lessons_(3,_4,_'Art') + lessons_(3,_5,_'Art')
#  + lessons_(3,_6,_'Art') + lessons_(3,_7,_'Art') + lessons_(3,_8,_'Art')
#  + lessons_(4,_1,_'Art') + lessons_(4,_2,_'Art') + lessons_(4,_3,_'Art')
#  + lessons_(4,_4,_'Art') + lessons_(4,_5,_'Art') + lessons_(4,_6,_'Art')
#  + lessons_(4,_7,_'Art') + lessons_(4,_8,_'Art') + lessons_(5,_1,_'Art')
#  + lessons_(5,_2,_'Art') + lessons_(5,_3,_'Art') + lessons_(5,_4,_'Art')
#  + lessons_(5,_5,_'Art') + lessons_(5,_6,_'Art') + lessons_(5,_7,_'Art')
#  + lessons_(5,_8,_'Art') + lessons_(6,_1,_'Art') + lessons_(6,_2,_'Art')
#  + lessons_(6,_3,_'Art') + lessons_(6,_4,_'Art') + lessons_(6,_5,_'Art')
#  + lessons_(6,_6,_'Art') + lessons_(6,_7,_'Art') + lessons_(6,_8,_'Art') = 2
#
# _C9: lessons_(1,_1,_'Art') + lessons_(1,_1,_'Bible')
#  + lessons_(1,_1,_'Education') + lessons_(1,_1,_'Hebrew')
#  + lessons_(1,_1,_'Math') + lessons_(1,_1,_'Music')
#  + lessons_(1,_1,_'Science') + lessons_(1,_1,_'Sport') + lessons_(1,_2,_'Art')
#  + lessons_(1,_2,_'Bible') + lessons_(1,_2,_'Education')
#  + lessons_(1,_2,_'Hebrew') + lessons_(1,_2,_'Math') + lessons_(1,_2,_'Music')
#  + lessons_(1,_2,_'Science') + lessons_(1,_2,_'Sport') + lessons_(1,_3,_'Art')
#  + lessons_(1,_3,_'Bible') + lessons_(1,_3,_'Education')
#  + lessons_(1,_3,_'Hebrew') + lessons_(1,_3,_'Math') + lessons_(1,_3,_'Music')
#  + lessons_(1,_3,_'Science') + lessons_(1,_3,_'Sport') + lessons_(1,_4,_'Art')
#  + lessons_(1,_4,_'Bible') + lessons_(1,_4,_'Education')
#  + lessons_(1,_4,_'Hebrew') + lessons_(1,_4,_'Math') + lessons_(1,_4,_'Music')
#  + lessons_(1,_4,_'Science') + lessons_(1,_4,_'Sport') + lessons_(1,_5,_'Art')
#  + lessons_(1,_5,_'Bible') + lessons_(1,_5,_'Education')
#  + lessons_(1,_5,_'Hebrew') + lessons_(1,_5,_'Math') + lessons_(1,_5,_'Music')
#  + lessons_(1,_5,_'Science') + lessons_(1,_5,_'Sport') + lessons_(1,_6,_'Art')
#  + lessons_(1,_6,_'Bible') + lessons_(1,_6,_'Education')
#  + lessons_(1,_6,_'Hebrew') + lessons_(1,_6,_'Math') + lessons_(1,_6,_'Music')
#  + lessons_(1,_6,_'Science') + lessons_(1,_6,_'Sport') + lessons_(1,_7,_'Art')
#  + lessons_(1,_7,_'Bible') + lessons_(1,_7,_'Education')
#  + lessons_(1,_7,_'Hebrew') + lessons_(1,_7,_'Math') + lessons_(1,_7,_'Music')
#  + lessons_(1,_7,_'Science') + lessons_(1,_7,_'Sport') + lessons_(1,_8,_'Art')
#  + lessons_(1,_8,_'Bible') + lessons_(1,_8,_'Education')
#  + lessons_(1,_8,_'Hebrew') + lessons_(1,_8,_'Math') + lessons_(1,_8,_'Music')
#  + lessons_(1,_8,_'Science') + lessons_(1,_8,_'Sport') <= 6
#
# _C10: lessons_(2,_1,_'Art') + lessons_(2,_1,_'Bible')
#  + lessons_(2,_1,_'Education') + lessons_(2,_1,_'Hebrew')
#  + lessons_(2,_1,_'Math') + lessons_(2,_1,_'Music')
#  + lessons_(2,_1,_'Science') + lessons_(2,_1,_'Sport') + lessons_(2,_2,_'Art')
#  + lessons_(2,_2,_'Bible') + lessons_(2,_2,_'Education')
#  + lessons_(2,_2,_'Hebrew') + lessons_(2,_2,_'Math') + lessons_(2,_2,_'Music')
#  + lessons_(2,_2,_'Science') + lessons_(2,_2,_'Sport') + lessons_(2,_3,_'Art')
#  + lessons_(2,_3,_'Bible') + lessons_(2,_3,_'Education')
#  + lessons_(2,_3,_'Hebrew') + lessons_(2,_3,_'Math') + lessons_(2,_3,_'Music')
#  + lessons_(2,_3,_'Science') + lessons_(2,_3,_'Sport') + lessons_(2,_4,_'Art')
#  + lessons_(2,_4,_'Bible') + lessons_(2,_4,_'Education')
#  + lessons_(2,_4,_'Hebrew') + lessons_(2,_4,_'Math') + lessons_(2,_4,_'Music')
#  + lessons_(2,_4,_'Science') + lessons_(2,_4,_'Sport') + lessons_(2,_5,_'Art')
#  + lessons_(2,_5,_'Bible') + lessons_(2,_5,_'Education')
#  + lessons_(2,_5,_'Hebrew') + lessons_(2,_5,_'Math') + lessons_(2,_5,_'Music')
#  + lessons_(2,_5,_'Science') + lessons_(2,_5,_'Sport') + lessons_(2,_6,_'Art')
#  + lessons_(2,_6,_'Bible') + lessons_(2,_6,_'Education')
#  + lessons_(2,_6,_'Hebrew') + lessons_(2,_6,_'Math') + lessons_(2,_6,_'Music')
#  + lessons_(2,_6,_'Science') + lessons_(2,_6,_'Sport') + lessons_(2,_7,_'Art')
#  + lessons_(2,_7,_'Bible') + lessons_(2,_7,_'Education')
#  + lessons_(2,_7,_'Hebrew') + lessons_(2,_7,_'Math') + lessons_(2,_7,_'Music')
#  + lessons_(2,_7,_'Science') + lessons_(2,_7,_'Sport') + lessons_(2,_8,_'Art')
#  + lessons_(2,_8,_'Bible') + lessons_(2,_8,_'Education')
#  + lessons_(2,_8,_'Hebrew') + lessons_(2,_8,_'Math') + lessons_(2,_8,_'Music')
#  + lessons_(2,_8,_'Science') + lessons_(2,_8,_'Sport') <= 6
#
# _C11: lessons_(3,_1,_'Art') + lessons_(3,_1,_'Bible')
#  + lessons_(3,_1,_'Education') + lessons_(3,_1,_'Hebrew')
#  + lessons_(3,_1,_'Math') + lessons_(3,_1,_'Music')
#  + lessons_(3,_1,_'Science') + lessons_(3,_1,_'Sport') + lessons_(3,_2,_'Art')
#  + lessons_(3,_2,_'Bible') + lessons_(3,_2,_'Education')
#  + lessons_(3,_2,_'Hebrew') + lessons_(3,_2,_'Math') + lessons_(3,_2,_'Music')
#  + lessons_(3,_2,_'Science') + lessons_(3,_2,_'Sport') + lessons_(3,_3,_'Art')
#  + lessons_(3,_3,_'Bible') + lessons_(3,_3,_'Education')
#  + lessons_(3,_3,_'Hebrew') + lessons_(3,_3,_'Math') + lessons_(3,_3,_'Music')
#  + lessons_(3,_3,_'Science') + lessons_(3,_3,_'Sport') + lessons_(3,_4,_'Art')
#  + lessons_(3,_4,_'Bible') + lessons_(3,_4,_'Education')
#  + lessons_(3,_4,_'Hebrew') + lessons_(3,_4,_'Math') + lessons_(3,_4,_'Music')
#  + lessons_(3,_4,_'Science') + lessons_(3,_4,_'Sport') + lessons_(3,_5,_'Art')
#  + lessons_(3,_5,_'Bible') + lessons_(3,_5,_'Education')
#  + lessons_(3,_5,_'Hebrew') + lessons_(3,_5,_'Math') + lessons_(3,_5,_'Music')
#  + lessons_(3,_5,_'Science') + lessons_(3,_5,_'Sport') + lessons_(3,_6,_'Art')
#  + lessons_(3,_6,_'Bible') + lessons_(3,_6,_'Education')
#  + lessons_(3,_6,_'Hebrew') + lessons_(3,_6,_'Math') + lessons_(3,_6,_'Music')
#  + lessons_(3,_6,_'Science') + lessons_(3,_6,_'Sport') + lessons_(3,_7,_'Art')
#  + lessons_(3,_7,_'Bible') + lessons_(3,_7,_'Education')
#  + lessons_(3,_7,_'Hebrew') + lessons_(3,_7,_'Math') + lessons_(3,_7,_'Music')
#  + lessons_(3,_7,_'Science') + lessons_(3,_7,_'Sport') + lessons_(3,_8,_'Art')
#  + lessons_(3,_8,_'Bible') + lessons_(3,_8,_'Education')
#  + lessons_(3,_8,_'Hebrew') + lessons_(3,_8,_'Math') + lessons_(3,_8,_'Music')
#  + lessons_(3,_8,_'Science') + lessons_(3,_8,_'Sport') <= 6
#
# _C12: lessons_(4,_1,_'Art') + lessons_(4,_1,_'Bible')
#  + lessons_(4,_1,_'Education') + lessons_(4,_1,_'Hebrew')
#  + lessons_(4,_1,_'Math') + lessons_(4,_1,_'Music')
#  + lessons_(4,_1,_'Science') + lessons_(4,_1,_'Sport') + lessons_(4,_2,_'Art')
#  + lessons_(4,_2,_'Bible') + lessons_(4,_2,_'Education')
#  + lessons_(4,_2,_'Hebrew') + lessons_(4,_2,_'Math') + lessons_(4,_2,_'Music')
#  + lessons_(4,_2,_'Science') + lessons_(4,_2,_'Sport') + lessons_(4,_3,_'Art')
#  + lessons_(4,_3,_'Bible') + lessons_(4,_3,_'Education')
#  + lessons_(4,_3,_'Hebrew') + lessons_(4,_3,_'Math') + lessons_(4,_3,_'Music')
#  + lessons_(4,_3,_'Science') + lessons_(4,_3,_'Sport') + lessons_(4,_4,_'Art')
#  + lessons_(4,_4,_'Bible') + lessons_(4,_4,_'Education')
#  + lessons_(4,_4,_'Hebrew') + lessons_(4,_4,_'Math') + lessons_(4,_4,_'Music')
#  + lessons_(4,_4,_'Science') + lessons_(4,_4,_'Sport') + lessons_(4,_5,_'Art')
#  + lessons_(4,_5,_'Bible') + lessons_(4,_5,_'Education')
#  + lessons_(4,_5,_'Hebrew') + lessons_(4,_5,_'Math') + lessons_(4,_5,_'Music')
#  + lessons_(4,_5,_'Science') + lessons_(4,_5,_'Sport') + lessons_(4,_6,_'Art')
#  + lessons_(4,_6,_'Bible') + lessons_(4,_6,_'Education')
#  + lessons_(4,_6,_'Hebrew') + lessons_(4,_6,_'Math') + lessons_(4,_6,_'Music')
#  + lessons_(4,_6,_'Science') + lessons_(4,_6,_'Sport') + lessons_(4,_7,_'Art')
#  + lessons_(4,_7,_'Bible') + lessons_(4,_7,_'Education')
#  + lessons_(4,_7,_'Hebrew') + lessons_(4,_7,_'Math') + lessons_(4,_7,_'Music')
#  + lessons_(4,_7,_'Science') + lessons_(4,_7,_'Sport') + lessons_(4,_8,_'Art')
#  + lessons_(4,_8,_'Bible') + lessons_(4,_8,_'Education')
#  + lessons_(4,_8,_'Hebrew') + lessons_(4,_8,_'Math') + lessons_(4,_8,_'Music')
#  + lessons_(4,_8,_'Science') + lessons_(4,_8,_'Sport') <= 6
#
# _C13: lessons_(5,_1,_'Art') + lessons_(5,_1,_'Bible')
#  + lessons_(5,_1,_'Education') + lessons_(5,_1,_'Hebrew')
#  + lessons_(5,_1,_'Math') + lessons_(5,_1,_'Music')
#  + lessons_(5,_1,_'Science') + lessons_(5,_1,_'Sport') + lessons_(5,_2,_'Art')
#  + lessons_(5,_2,_'Bible') + lessons_(5,_2,_'Education')
#  + lessons_(5,_2,_'Hebrew') + lessons_(5,_2,_'Math') + lessons_(5,_2,_'Music')
#  + lessons_(5,_2,_'Science') + lessons_(5,_2,_'Sport') + lessons_(5,_3,_'Art')
#  + lessons_(5,_3,_'Bible') + lessons_(5,_3,_'Education')
#  + lessons_(5,_3,_'Hebrew') + lessons_(5,_3,_'Math') + lessons_(5,_3,_'Music')
#  + lessons_(5,_3,_'Science') + lessons_(5,_3,_'Sport') + lessons_(5,_4,_'Art')
#  + lessons_(5,_4,_'Bible') + lessons_(5,_4,_'Education')
#  + lessons_(5,_4,_'Hebrew') + lessons_(5,_4,_'Math') + lessons_(5,_4,_'Music')
#  + lessons_(5,_4,_'Science') + lessons_(5,_4,_'Sport') + lessons_(5,_5,_'Art')
#  + lessons_(5,_5,_'Bible') + lessons_(5,_5,_'Education')
#  + lessons_(5,_5,_'Hebrew') + lessons_(5,_5,_'Math') + lessons_(5,_5,_'Music')
#  + lessons_(5,_5,_'Science') + lessons_(5,_5,_'Sport') + lessons_(5,_6,_'Art')
#  + lessons_(5,_6,_'Bible') + lessons_(5,_6,_'Education')
#  + lessons_(5,_6,_'Hebrew') + lessons_(5,_6,_'Math') + lessons_(5,_6,_'Music')
#  + lessons_(5,_6,_'Science') + lessons_(5,_6,_'Sport') + lessons_(5,_7,_'Art')
#  + lessons_(5,_7,_'Bible') + lessons_(5,_7,_'Education')
#  + lessons_(5,_7,_'Hebrew') + lessons_(5,_7,_'Math') + lessons_(5,_7,_'Music')
#  + lessons_(5,_7,_'Science') + lessons_(5,_7,_'Sport') + lessons_(5,_8,_'Art')
#  + lessons_(5,_8,_'Bible') + lessons_(5,_8,_'Education')
#  + lessons_(5,_8,_'Hebrew') + lessons_(5,_8,_'Math') + lessons_(5,_8,_'Music')
#  + lessons_(5,_8,_'Science') + lessons_(5,_8,_'Sport') <= 6
#
# _C14: lessons_(6,_1,_'Art') + lessons_(6,_1,_'Bible')
#  + lessons_(6,_1,_'Education') + lessons_(6,_1,_'Hebrew')
#  + lessons_(6,_1,_'Math') + lessons_(6,_1,_'Music')
#  + lessons_(6,_1,_'Science') + lessons_(6,_1,_'Sport') + lessons_(6,_2,_'Art')
#  + lessons_(6,_2,_'Bible') + lessons_(6,_2,_'Education')
#  + lessons_(6,_2,_'Hebrew') + lessons_(6,_2,_'Math') + lessons_(6,_2,_'Music')
#  + lessons_(6,_2,_'Science') + lessons_(6,_2,_'Sport') + lessons_(6,_3,_'Art')
#  + lessons_(6,_3,_'Bible') + lessons_(6,_3,_'Education')
#  + lessons_(6,_3,_'Hebrew') + lessons_(6,_3,_'Math') + lessons_(6,_3,_'Music')
#  + lessons_(6,_3,_'Science') + lessons_(6,_3,_'Sport') + lessons_(6,_4,_'Art')
#  + lessons_(6,_4,_'Bible') + lessons_(6,_4,_'Education')
#  + lessons_(6,_4,_'Hebrew') + lessons_(6,_4,_'Math') + lessons_(6,_4,_'Music')
#  + lessons_(6,_4,_'Science') + lessons_(6,_4,_'Sport') + lessons_(6,_5,_'Art')
#  + lessons_(6,_5,_'Bible') + lessons_(6,_5,_'Education')
#  + lessons_(6,_5,_'Hebrew') + lessons_(6,_5,_'Math') + lessons_(6,_5,_'Music')
#  + lessons_(6,_5,_'Science') + lessons_(6,_5,_'Sport') + lessons_(6,_6,_'Art')
#  + lessons_(6,_6,_'Bible') + lessons_(6,_6,_'Education')
#  + lessons_(6,_6,_'Hebrew') + lessons_(6,_6,_'Math') + lessons_(6,_6,_'Music')
#  + lessons_(6,_6,_'Science') + lessons_(6,_6,_'Sport') + lessons_(6,_7,_'Art')
#  + lessons_(6,_7,_'Bible') + lessons_(6,_7,_'Education')
#  + lessons_(6,_7,_'Hebrew') + lessons_(6,_7,_'Math') + lessons_(6,_7,_'Music')
#  + lessons_(6,_7,_'Science') + lessons_(6,_7,_'Sport') + lessons_(6,_8,_'Art')
#  + lessons_(6,_8,_'Bible') + lessons_(6,_8,_'Education')
#  + lessons_(6,_8,_'Hebrew') + lessons_(6,_8,_'Math') + lessons_(6,_8,_'Music')
#  + lessons_(6,_8,_'Science') + lessons_(6,_8,_'Sport') <= 6
#
# VARIABLES
# 0 <= lessons_(1,_1,_'Art') <= 1 Integer
# 0 <= lessons_(1,_1,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_1,_'Education') <= 1 Integer
# 0 <= lessons_(1,_1,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_1,_'Math') <= 1 Integer
# 0 <= lessons_(1,_1,_'Music') <= 1 Integer
# 0 <= lessons_(1,_1,_'Science') <= 1 Integer
# 0 <= lessons_(1,_1,_'Sport') <= 1 Integer
# 0 <= lessons_(1,_2,_'Art') <= 1 Integer
# 0 <= lessons_(1,_2,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_2,_'Education') <= 1 Integer
# 0 <= lessons_(1,_2,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_2,_'Math') <= 1 Integer
# 0 <= lessons_(1,_2,_'Music') <= 1 Integer
# 0 <= lessons_(1,_2,_'Science') <= 1 Integer
# 0 <= lessons_(1,_2,_'Sport') <= 1 Integer
# 0 <= lessons_(1,_3,_'Art') <= 1 Integer
# 0 <= lessons_(1,_3,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_3,_'Education') <= 1 Integer
# 0 <= lessons_(1,_3,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_3,_'Math') <= 1 Integer
# 0 <= lessons_(1,_3,_'Music') <= 1 Integer
# 0 <= lessons_(1,_3,_'Science') <= 1 Integer
# 0 <= lessons_(1,_3,_'Sport') <= 1 Integer
# 0 <= lessons_(1,_4,_'Art') <= 1 Integer
# 0 <= lessons_(1,_4,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_4,_'Education') <= 1 Integer
# 0 <= lessons_(1,_4,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_4,_'Math') <= 1 Integer
# 0 <= lessons_(1,_4,_'Music') <= 1 Integer
# 0 <= lessons_(1,_4,_'Science') <= 1 Integer
# 0 <= lessons_(1,_4,_'Sport') <= 1 Integer
# 0 <= lessons_(1,_5,_'Art') <= 1 Integer
# 0 <= lessons_(1,_5,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_5,_'Education') <= 1 Integer
# 0 <= lessons_(1,_5,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_5,_'Math') <= 1 Integer
# 0 <= lessons_(1,_5,_'Music') <= 1 Integer
# 0 <= lessons_(1,_5,_'Science') <= 1 Integer
# 0 <= lessons_(1,_5,_'Sport') <= 1 Integer
# 0 <= lessons_(1,_6,_'Art') <= 1 Integer
# 0 <= lessons_(1,_6,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_6,_'Education') <= 1 Integer
# 0 <= lessons_(1,_6,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_6,_'Math') <= 1 Integer
# 0 <= lessons_(1,_6,_'Music') <= 1 Integer
# 0 <= lessons_(1,_6,_'Science') <= 1 Integer
# 0 <= lessons_(1,_6,_'Sport') <= 1 Integer
# 0 <= lessons_(1,_7,_'Art') <= 1 Integer
# 0 <= lessons_(1,_7,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_7,_'Education') <= 1 Integer
# 0 <= lessons_(1,_7,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_7,_'Math') <= 1 Integer
# 0 <= lessons_(1,_7,_'Music') <= 1 Integer
# 0 <= lessons_(1,_7,_'Science') <= 1 Integer
# 0 <= lessons_(1,_7,_'Sport') <= 1 Integer
# 0 <= lessons_(1,_8,_'Art') <= 1 Integer
# 0 <= lessons_(1,_8,_'Bible') <= 1 Integer
# 0 <= lessons_(1,_8,_'Education') <= 1 Integer
# 0 <= lessons_(1,_8,_'Hebrew') <= 1 Integer
# 0 <= lessons_(1,_8,_'Math') <= 1 Integer
# 0 <= lessons_(1,_8,_'Music') <= 1 Integer
# 0 <= lessons_(1,_8,_'Science') <= 1 Integer
# 0 <= lessons_(1,_8,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_1,_'Art') <= 1 Integer
# 0 <= lessons_(2,_1,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_1,_'Education') <= 1 Integer
# 0 <= lessons_(2,_1,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_1,_'Math') <= 1 Integer
# 0 <= lessons_(2,_1,_'Music') <= 1 Integer
# 0 <= lessons_(2,_1,_'Science') <= 1 Integer
# 0 <= lessons_(2,_1,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_2,_'Art') <= 1 Integer
# 0 <= lessons_(2,_2,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_2,_'Education') <= 1 Integer
# 0 <= lessons_(2,_2,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_2,_'Math') <= 1 Integer
# 0 <= lessons_(2,_2,_'Music') <= 1 Integer
# 0 <= lessons_(2,_2,_'Science') <= 1 Integer
# 0 <= lessons_(2,_2,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_3,_'Art') <= 1 Integer
# 0 <= lessons_(2,_3,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_3,_'Education') <= 1 Integer
# 0 <= lessons_(2,_3,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_3,_'Math') <= 1 Integer
# 0 <= lessons_(2,_3,_'Music') <= 1 Integer
# 0 <= lessons_(2,_3,_'Science') <= 1 Integer
# 0 <= lessons_(2,_3,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_4,_'Art') <= 1 Integer
# 0 <= lessons_(2,_4,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_4,_'Education') <= 1 Integer
# 0 <= lessons_(2,_4,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_4,_'Math') <= 1 Integer
# 0 <= lessons_(2,_4,_'Music') <= 1 Integer
# 0 <= lessons_(2,_4,_'Science') <= 1 Integer
# 0 <= lessons_(2,_4,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_5,_'Art') <= 1 Integer
# 0 <= lessons_(2,_5,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_5,_'Education') <= 1 Integer
# 0 <= lessons_(2,_5,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_5,_'Math') <= 1 Integer
# 0 <= lessons_(2,_5,_'Music') <= 1 Integer
# 0 <= lessons_(2,_5,_'Science') <= 1 Integer
# 0 <= lessons_(2,_5,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_6,_'Art') <= 1 Integer
# 0 <= lessons_(2,_6,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_6,_'Education') <= 1 Integer
# 0 <= lessons_(2,_6,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_6,_'Math') <= 1 Integer
# 0 <= lessons_(2,_6,_'Music') <= 1 Integer
# 0 <= lessons_(2,_6,_'Science') <= 1 Integer
# 0 <= lessons_(2,_6,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_7,_'Art') <= 1 Integer
# 0 <= lessons_(2,_7,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_7,_'Education') <= 1 Integer
# 0 <= lessons_(2,_7,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_7,_'Math') <= 1 Integer
# 0 <= lessons_(2,_7,_'Music') <= 1 Integer
# 0 <= lessons_(2,_7,_'Science') <= 1 Integer
# 0 <= lessons_(2,_7,_'Sport') <= 1 Integer
# 0 <= lessons_(2,_8,_'Art') <= 1 Integer
# 0 <= lessons_(2,_8,_'Bible') <= 1 Integer
# 0 <= lessons_(2,_8,_'Education') <= 1 Integer
# 0 <= lessons_(2,_8,_'Hebrew') <= 1 Integer
# 0 <= lessons_(2,_8,_'Math') <= 1 Integer
# 0 <= lessons_(2,_8,_'Music') <= 1 Integer
# 0 <= lessons_(2,_8,_'Science') <= 1 Integer
# 0 <= lessons_(2,_8,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_1,_'Art') <= 1 Integer
# 0 <= lessons_(3,_1,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_1,_'Education') <= 1 Integer
# 0 <= lessons_(3,_1,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_1,_'Math') <= 1 Integer
# 0 <= lessons_(3,_1,_'Music') <= 1 Integer
# 0 <= lessons_(3,_1,_'Science') <= 1 Integer
# 0 <= lessons_(3,_1,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_2,_'Art') <= 1 Integer
# 0 <= lessons_(3,_2,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_2,_'Education') <= 1 Integer
# 0 <= lessons_(3,_2,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_2,_'Math') <= 1 Integer
# 0 <= lessons_(3,_2,_'Music') <= 1 Integer
# 0 <= lessons_(3,_2,_'Science') <= 1 Integer
# 0 <= lessons_(3,_2,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_3,_'Art') <= 1 Integer
# 0 <= lessons_(3,_3,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_3,_'Education') <= 1 Integer
# 0 <= lessons_(3,_3,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_3,_'Math') <= 1 Integer
# 0 <= lessons_(3,_3,_'Music') <= 1 Integer
# 0 <= lessons_(3,_3,_'Science') <= 1 Integer
# 0 <= lessons_(3,_3,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_4,_'Art') <= 1 Integer
# 0 <= lessons_(3,_4,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_4,_'Education') <= 1 Integer
# 0 <= lessons_(3,_4,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_4,_'Math') <= 1 Integer
# 0 <= lessons_(3,_4,_'Music') <= 1 Integer
# 0 <= lessons_(3,_4,_'Science') <= 1 Integer
# 0 <= lessons_(3,_4,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_5,_'Art') <= 1 Integer
# 0 <= lessons_(3,_5,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_5,_'Education') <= 1 Integer
# 0 <= lessons_(3,_5,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_5,_'Math') <= 1 Integer
# 0 <= lessons_(3,_5,_'Music') <= 1 Integer
# 0 <= lessons_(3,_5,_'Science') <= 1 Integer
# 0 <= lessons_(3,_5,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_6,_'Art') <= 1 Integer
# 0 <= lessons_(3,_6,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_6,_'Education') <= 1 Integer
# 0 <= lessons_(3,_6,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_6,_'Math') <= 1 Integer
# 0 <= lessons_(3,_6,_'Music') <= 1 Integer
# 0 <= lessons_(3,_6,_'Science') <= 1 Integer
# 0 <= lessons_(3,_6,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_7,_'Art') <= 1 Integer
# 0 <= lessons_(3,_7,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_7,_'Education') <= 1 Integer
# 0 <= lessons_(3,_7,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_7,_'Math') <= 1 Integer
# 0 <= lessons_(3,_7,_'Music') <= 1 Integer
# 0 <= lessons_(3,_7,_'Science') <= 1 Integer
# 0 <= lessons_(3,_7,_'Sport') <= 1 Integer
# 0 <= lessons_(3,_8,_'Art') <= 1 Integer
# 0 <= lessons_(3,_8,_'Bible') <= 1 Integer
# 0 <= lessons_(3,_8,_'Education') <= 1 Integer
# 0 <= lessons_(3,_8,_'Hebrew') <= 1 Integer
# 0 <= lessons_(3,_8,_'Math') <= 1 Integer
# 0 <= lessons_(3,_8,_'Music') <= 1 Integer
# 0 <= lessons_(3,_8,_'Science') <= 1 Integer
# 0 <= lessons_(3,_8,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_1,_'Art') <= 1 Integer
# 0 <= lessons_(4,_1,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_1,_'Education') <= 1 Integer
# 0 <= lessons_(4,_1,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_1,_'Math') <= 1 Integer
# 0 <= lessons_(4,_1,_'Music') <= 1 Integer
# 0 <= lessons_(4,_1,_'Science') <= 1 Integer
# 0 <= lessons_(4,_1,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_2,_'Art') <= 1 Integer
# 0 <= lessons_(4,_2,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_2,_'Education') <= 1 Integer
# 0 <= lessons_(4,_2,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_2,_'Math') <= 1 Integer
# 0 <= lessons_(4,_2,_'Music') <= 1 Integer
# 0 <= lessons_(4,_2,_'Science') <= 1 Integer
# 0 <= lessons_(4,_2,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_3,_'Art') <= 1 Integer
# 0 <= lessons_(4,_3,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_3,_'Education') <= 1 Integer
# 0 <= lessons_(4,_3,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_3,_'Math') <= 1 Integer
# 0 <= lessons_(4,_3,_'Music') <= 1 Integer
# 0 <= lessons_(4,_3,_'Science') <= 1 Integer
# 0 <= lessons_(4,_3,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_4,_'Art') <= 1 Integer
# 0 <= lessons_(4,_4,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_4,_'Education') <= 1 Integer
# 0 <= lessons_(4,_4,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_4,_'Math') <= 1 Integer
# 0 <= lessons_(4,_4,_'Music') <= 1 Integer
# 0 <= lessons_(4,_4,_'Science') <= 1 Integer
# 0 <= lessons_(4,_4,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_5,_'Art') <= 1 Integer
# 0 <= lessons_(4,_5,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_5,_'Education') <= 1 Integer
# 0 <= lessons_(4,_5,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_5,_'Math') <= 1 Integer
# 0 <= lessons_(4,_5,_'Music') <= 1 Integer
# 0 <= lessons_(4,_5,_'Science') <= 1 Integer
# 0 <= lessons_(4,_5,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_6,_'Art') <= 1 Integer
# 0 <= lessons_(4,_6,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_6,_'Education') <= 1 Integer
# 0 <= lessons_(4,_6,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_6,_'Math') <= 1 Integer
# 0 <= lessons_(4,_6,_'Music') <= 1 Integer
# 0 <= lessons_(4,_6,_'Science') <= 1 Integer
# 0 <= lessons_(4,_6,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_7,_'Art') <= 1 Integer
# 0 <= lessons_(4,_7,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_7,_'Education') <= 1 Integer
# 0 <= lessons_(4,_7,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_7,_'Math') <= 1 Integer
# 0 <= lessons_(4,_7,_'Music') <= 1 Integer
# 0 <= lessons_(4,_7,_'Science') <= 1 Integer
# 0 <= lessons_(4,_7,_'Sport') <= 1 Integer
# 0 <= lessons_(4,_8,_'Art') <= 1 Integer
# 0 <= lessons_(4,_8,_'Bible') <= 1 Integer
# 0 <= lessons_(4,_8,_'Education') <= 1 Integer
# 0 <= lessons_(4,_8,_'Hebrew') <= 1 Integer
# 0 <= lessons_(4,_8,_'Math') <= 1 Integer
# 0 <= lessons_(4,_8,_'Music') <= 1 Integer
# 0 <= lessons_(4,_8,_'Science') <= 1 Integer
# 0 <= lessons_(4,_8,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_1,_'Art') <= 1 Integer
# 0 <= lessons_(5,_1,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_1,_'Education') <= 1 Integer
# 0 <= lessons_(5,_1,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_1,_'Math') <= 1 Integer
# 0 <= lessons_(5,_1,_'Music') <= 1 Integer
# 0 <= lessons_(5,_1,_'Science') <= 1 Integer
# 0 <= lessons_(5,_1,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_2,_'Art') <= 1 Integer
# 0 <= lessons_(5,_2,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_2,_'Education') <= 1 Integer
# 0 <= lessons_(5,_2,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_2,_'Math') <= 1 Integer
# 0 <= lessons_(5,_2,_'Music') <= 1 Integer
# 0 <= lessons_(5,_2,_'Science') <= 1 Integer
# 0 <= lessons_(5,_2,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_3,_'Art') <= 1 Integer
# 0 <= lessons_(5,_3,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_3,_'Education') <= 1 Integer
# 0 <= lessons_(5,_3,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_3,_'Math') <= 1 Integer
# 0 <= lessons_(5,_3,_'Music') <= 1 Integer
# 0 <= lessons_(5,_3,_'Science') <= 1 Integer
# 0 <= lessons_(5,_3,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_4,_'Art') <= 1 Integer
# 0 <= lessons_(5,_4,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_4,_'Education') <= 1 Integer
# 0 <= lessons_(5,_4,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_4,_'Math') <= 1 Integer
# 0 <= lessons_(5,_4,_'Music') <= 1 Integer
# 0 <= lessons_(5,_4,_'Science') <= 1 Integer
# 0 <= lessons_(5,_4,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_5,_'Art') <= 1 Integer
# 0 <= lessons_(5,_5,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_5,_'Education') <= 1 Integer
# 0 <= lessons_(5,_5,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_5,_'Math') <= 1 Integer
# 0 <= lessons_(5,_5,_'Music') <= 1 Integer
# 0 <= lessons_(5,_5,_'Science') <= 1 Integer
# 0 <= lessons_(5,_5,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_6,_'Art') <= 1 Integer
# 0 <= lessons_(5,_6,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_6,_'Education') <= 1 Integer
# 0 <= lessons_(5,_6,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_6,_'Math') <= 1 Integer
# 0 <= lessons_(5,_6,_'Music') <= 1 Integer
# 0 <= lessons_(5,_6,_'Science') <= 1 Integer
# 0 <= lessons_(5,_6,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_7,_'Art') <= 1 Integer
# 0 <= lessons_(5,_7,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_7,_'Education') <= 1 Integer
# 0 <= lessons_(5,_7,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_7,_'Math') <= 1 Integer
# 0 <= lessons_(5,_7,_'Music') <= 1 Integer
# 0 <= lessons_(5,_7,_'Science') <= 1 Integer
# 0 <= lessons_(5,_7,_'Sport') <= 1 Integer
# 0 <= lessons_(5,_8,_'Art') <= 1 Integer
# 0 <= lessons_(5,_8,_'Bible') <= 1 Integer
# 0 <= lessons_(5,_8,_'Education') <= 1 Integer
# 0 <= lessons_(5,_8,_'Hebrew') <= 1 Integer
# 0 <= lessons_(5,_8,_'Math') <= 1 Integer
# 0 <= lessons_(5,_8,_'Music') <= 1 Integer
# 0 <= lessons_(5,_8,_'Science') <= 1 Integer
# 0 <= lessons_(5,_8,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_1,_'Art') <= 1 Integer
# 0 <= lessons_(6,_1,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_1,_'Education') <= 1 Integer
# 0 <= lessons_(6,_1,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_1,_'Math') <= 1 Integer
# 0 <= lessons_(6,_1,_'Music') <= 1 Integer
# 0 <= lessons_(6,_1,_'Science') <= 1 Integer
# 0 <= lessons_(6,_1,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_2,_'Art') <= 1 Integer
# 0 <= lessons_(6,_2,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_2,_'Education') <= 1 Integer
# 0 <= lessons_(6,_2,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_2,_'Math') <= 1 Integer
# 0 <= lessons_(6,_2,_'Music') <= 1 Integer
# 0 <= lessons_(6,_2,_'Science') <= 1 Integer
# 0 <= lessons_(6,_2,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_3,_'Art') <= 1 Integer
# 0 <= lessons_(6,_3,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_3,_'Education') <= 1 Integer
# 0 <= lessons_(6,_3,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_3,_'Math') <= 1 Integer
# 0 <= lessons_(6,_3,_'Music') <= 1 Integer
# 0 <= lessons_(6,_3,_'Science') <= 1 Integer
# 0 <= lessons_(6,_3,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_4,_'Art') <= 1 Integer
# 0 <= lessons_(6,_4,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_4,_'Education') <= 1 Integer
# 0 <= lessons_(6,_4,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_4,_'Math') <= 1 Integer
# 0 <= lessons_(6,_4,_'Music') <= 1 Integer
# 0 <= lessons_(6,_4,_'Science') <= 1 Integer
# 0 <= lessons_(6,_4,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_5,_'Art') <= 1 Integer
# 0 <= lessons_(6,_5,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_5,_'Education') <= 1 Integer
# 0 <= lessons_(6,_5,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_5,_'Math') <= 1 Integer
# 0 <= lessons_(6,_5,_'Music') <= 1 Integer
# 0 <= lessons_(6,_5,_'Science') <= 1 Integer
# 0 <= lessons_(6,_5,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_6,_'Art') <= 1 Integer
# 0 <= lessons_(6,_6,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_6,_'Education') <= 1 Integer
# 0 <= lessons_(6,_6,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_6,_'Math') <= 1 Integer
# 0 <= lessons_(6,_6,_'Music') <= 1 Integer
# 0 <= lessons_(6,_6,_'Science') <= 1 Integer
# 0 <= lessons_(6,_6,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_7,_'Art') <= 1 Integer
# 0 <= lessons_(6,_7,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_7,_'Education') <= 1 Integer
# 0 <= lessons_(6,_7,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_7,_'Math') <= 1 Integer
# 0 <= lessons_(6,_7,_'Music') <= 1 Integer
# 0 <= lessons_(6,_7,_'Science') <= 1 Integer
# 0 <= lessons_(6,_7,_'Sport') <= 1 Integer
# 0 <= lessons_(6,_8,_'Art') <= 1 Integer
# 0 <= lessons_(6,_8,_'Bible') <= 1 Integer
# 0 <= lessons_(6,_8,_'Education') <= 1 Integer
# 0 <= lessons_(6,_8,_'Hebrew') <= 1 Integer
# 0 <= lessons_(6,_8,_'Math') <= 1 Integer
# 0 <= lessons_(6,_8,_'Music') <= 1 Integer
# 0 <= lessons_(6,_8,_'Science') <= 1 Integer
# 0 <= lessons_(6,_8,_'Sport') <= 1 Integer

# %%
model.solve()
pulp.LpStatus[model.status]
# Out:
# 'Optimal'

# %% [markdown]
# Let's take a look at the optimal production schedule output for each month from each factory. For ease of viewing we'll output the data to a pandas DataFrame.

# %%
for row in lessons_data.itertuples():
    print(lessons_status[row.Day, row.Hour, row.Lesson],\
          lessons_status[row.Day, row.Hour, row.Lesson].varValue)
# Out:
# lessons_(1,_1,_'Math') 0.0
# lessons_(1,_1,_'Science') 0.0
# lessons_(1,_1,_'Hebrew') 1.0
# lessons_(1,_1,_'Bible') 0.0
# lessons_(1,_1,_'Music') 0.0
# lessons_(1,_1,_'Education') 0.0
# lessons_(1,_1,_'Sport') 0.0
# lessons_(1,_1,_'Art') 0.0
# lessons_(1,_2,_'Math') 0.0
# lessons_(1,_2,_'Science') 0.0
# lessons_(1,_2,_'Hebrew') 1.0
# lessons_(1,_2,_'Bible') 0.0
# lessons_(1,_2,_'Music') 0.0
# lessons_(1,_2,_'Education') 0.0
# lessons_(1,_2,_'Sport') 0.0
# lessons_(1,_2,_'Art') 1.0
# lessons_(1,_3,_'Math') 0.0
# lessons_(1,_3,_'Science') 0.0
# lessons_(1,_3,_'Hebrew') 0.0
# lessons_(1,_3,_'Bible') 0.0
# lessons_(1,_3,_'Music') 0.0
# lessons_(1,_3,_'Education') 0.0
# lessons_(1,_3,_'Sport') 0.0
# lessons_(1,_3,_'Art') 0.0
# lessons_(1,_4,_'Math') 0.0
# lessons_(1,_4,_'Science') 0.0
# lessons_(1,_4,_'Hebrew') 0.0
# lessons_(1,_4,_'Bible') 0.0
# lessons_(1,_4,_'Music') 0.0
# lessons_(1,_4,_'Education') 0.0
# lessons_(1,_4,_'Sport') 0.0
# lessons_(1,_4,_'Art') 0.0
# lessons_(1,_5,_'Math') 0.0
# lessons_(1,_5,_'Science') 0.0
# lessons_(1,_5,_'Hebrew') 0.0
# lessons_(1,_5,_'Bible') 0.0
# lessons_(1,_5,_'Music') 0.0
# lessons_(1,_5,_'Education') 0.0
# lessons_(1,_5,_'Sport') 0.0
# lessons_(1,_5,_'Art') 0.0
# lessons_(1,_6,_'Math') 0.0
# lessons_(1,_6,_'Science') 0.0
# lessons_(1,_6,_'Hebrew') 0.0
# lessons_(1,_6,_'Bible') 0.0
# lessons_(1,_6,_'Music') 0.0
# lessons_(1,_6,_'Education') 0.0
# lessons_(1,_6,_'Sport') 0.0
# lessons_(1,_6,_'Art') 0.0
# lessons_(1,_7,_'Math') 0.0
# lessons_(1,_7,_'Science') 0.0
# lessons_(1,_7,_'Hebrew') 0.0
# lessons_(1,_7,_'Bible') 0.0
# lessons_(1,_7,_'Music') 0.0
# lessons_(1,_7,_'Education') 0.0
# lessons_(1,_7,_'Sport') 0.0
# lessons_(1,_7,_'Art') 0.0
# lessons_(1,_8,_'Math') 0.0
# lessons_(1,_8,_'Science') 0.0
# lessons_(1,_8,_'Hebrew') 0.0
# lessons_(1,_8,_'Bible') 0.0
# lessons_(1,_8,_'Music') 0.0
# lessons_(1,_8,_'Education') 0.0
# lessons_(1,_8,_'Sport') 0.0
# lessons_(1,_8,_'Art') 1.0
# lessons_(2,_1,_'Math') 0.0
# lessons_(2,_1,_'Science') 0.0
# lessons_(2,_1,_'Hebrew') 0.0
# lessons_(2,_1,_'Bible') 0.0
# lessons_(2,_1,_'Music') 0.0
# lessons_(2,_1,_'Education') 0.0
# lessons_(2,_1,_'Sport') 0.0
# lessons_(2,_1,_'Art') 0.0
# lessons_(2,_2,_'Math') 0.0
# lessons_(2,_2,_'Science') 0.0
# lessons_(2,_2,_'Hebrew') 0.0
# lessons_(2,_2,_'Bible') 0.0
# lessons_(2,_2,_'Music') 0.0
# lessons_(2,_2,_'Education') 0.0
# lessons_(2,_2,_'Sport') 0.0
# lessons_(2,_2,_'Art') 0.0
# lessons_(2,_3,_'Math') 0.0
# lessons_(2,_3,_'Science') 0.0
# lessons_(2,_3,_'Hebrew') 0.0
# lessons_(2,_3,_'Bible') 0.0
# lessons_(2,_3,_'Music') 0.0
# lessons_(2,_3,_'Education') 0.0
# lessons_(2,_3,_'Sport') 0.0
# lessons_(2,_3,_'Art') 0.0
# lessons_(2,_4,_'Math') 0.0
# lessons_(2,_4,_'Science') 0.0
# lessons_(2,_4,_'Hebrew') 0.0
# lessons_(2,_4,_'Bible') 0.0
# lessons_(2,_4,_'Music') 0.0
# lessons_(2,_4,_'Education') 0.0
# lessons_(2,_4,_'Sport') 0.0
# lessons_(2,_4,_'Art') 0.0
# lessons_(2,_5,_'Math') 0.0
# lessons_(2,_5,_'Science') 0.0
# lessons_(2,_5,_'Hebrew') 0.0
# lessons_(2,_5,_'Bible') 0.0
# lessons_(2,_5,_'Music') 0.0
# lessons_(2,_5,_'Education') 0.0
# lessons_(2,_5,_'Sport') 0.0
# lessons_(2,_5,_'Art') 0.0
# lessons_(2,_6,_'Math') 0.0
# lessons_(2,_6,_'Science') 0.0
# lessons_(2,_6,_'Hebrew') 0.0
# lessons_(2,_6,_'Bible') 0.0
# lessons_(2,_6,_'Music') 0.0
# lessons_(2,_6,_'Education') 0.0
# lessons_(2,_6,_'Sport') 0.0
# lessons_(2,_6,_'Art') 0.0
# lessons_(2,_7,_'Math') 0.0
# lessons_(2,_7,_'Science') 0.0
# lessons_(2,_7,_'Hebrew') 0.0
# lessons_(2,_7,_'Bible') 0.0
# lessons_(2,_7,_'Music') 0.0
# lessons_(2,_7,_'Education') 0.0
# lessons_(2,_7,_'Sport') 0.0
# lessons_(2,_7,_'Art') 0.0
# lessons_(2,_8,_'Math') 0.0
# lessons_(2,_8,_'Science') 0.0
# lessons_(2,_8,_'Hebrew') 0.0
# lessons_(2,_8,_'Bible') 0.0
# lessons_(2,_8,_'Music') 0.0
# lessons_(2,_8,_'Education') 0.0
# lessons_(2,_8,_'Sport') 0.0
# lessons_(2,_8,_'Art') 0.0
# lessons_(3,_1,_'Math') 1.0
# lessons_(3,_1,_'Science') 0.0
# lessons_(3,_1,_'Hebrew') 0.0
# lessons_(3,_1,_'Bible') 0.0
# lessons_(3,_1,_'Music') 0.0
# lessons_(3,_1,_'Education') 0.0
# lessons_(3,_1,_'Sport') 0.0
# lessons_(3,_1,_'Art') 0.0
# lessons_(3,_2,_'Math') 0.0
# lessons_(3,_2,_'Science') 1.0
# lessons_(3,_2,_'Hebrew') 0.0
# lessons_(3,_2,_'Bible') 0.0
# lessons_(3,_2,_'Music') 0.0
# lessons_(3,_2,_'Education') 0.0
# lessons_(3,_2,_'Sport') 1.0
# lessons_(3,_2,_'Art') 0.0
# lessons_(3,_3,_'Math') 1.0
# lessons_(3,_3,_'Science') 0.0
# lessons_(3,_3,_'Hebrew') 0.0
# lessons_(3,_3,_'Bible') 0.0
# lessons_(3,_3,_'Music') 0.0
# lessons_(3,_3,_'Education') 0.0
# lessons_(3,_3,_'Sport') 0.0
# lessons_(3,_3,_'Art') 0.0
# lessons_(3,_4,_'Math') 0.0
# lessons_(3,_4,_'Science') 0.0
# lessons_(3,_4,_'Hebrew') 0.0
# lessons_(3,_4,_'Bible') 0.0
# lessons_(3,_4,_'Music') 0.0
# lessons_(3,_4,_'Education') 0.0
# lessons_(3,_4,_'Sport') 0.0
# lessons_(3,_4,_'Art') 0.0
# lessons_(3,_5,_'Math') 0.0
# lessons_(3,_5,_'Science') 1.0
# lessons_(3,_5,_'Hebrew') 0.0
# lessons_(3,_5,_'Bible') 0.0
# lessons_(3,_5,_'Music') 0.0
# lessons_(3,_5,_'Education') 0.0
# lessons_(3,_5,_'Sport') 0.0
# lessons_(3,_5,_'Art') 0.0
# lessons_(3,_6,_'Math') 0.0
# lessons_(3,_6,_'Science') 0.0
# lessons_(3,_6,_'Hebrew') 0.0
# lessons_(3,_6,_'Bible') 0.0
# lessons_(3,_6,_'Music') 0.0
# lessons_(3,_6,_'Education') 0.0
# lessons_(3,_6,_'Sport') 0.0
# lessons_(3,_6,_'Art') 0.0
# lessons_(3,_7,_'Math') 0.0
# lessons_(3,_7,_'Science') 0.0
# lessons_(3,_7,_'Hebrew') 0.0
# lessons_(3,_7,_'Bible') 0.0
# lessons_(3,_7,_'Music') 0.0
# lessons_(3,_7,_'Education') 0.0
# lessons_(3,_7,_'Sport') 0.0
# lessons_(3,_7,_'Art') 0.0
# lessons_(3,_8,_'Math') 0.0
# lessons_(3,_8,_'Science') 0.0
# lessons_(3,_8,_'Hebrew') 0.0
# lessons_(3,_8,_'Bible') 0.0
# lessons_(3,_8,_'Music') 0.0
# lessons_(3,_8,_'Education') 0.0
# lessons_(3,_8,_'Sport') 1.0
# lessons_(3,_8,_'Art') 0.0
# lessons_(4,_1,_'Math') 0.0
# lessons_(4,_1,_'Science') 0.0
# lessons_(4,_1,_'Hebrew') 0.0
# lessons_(4,_1,_'Bible') 0.0
# lessons_(4,_1,_'Music') 0.0
# lessons_(4,_1,_'Education') 0.0
# lessons_(4,_1,_'Sport') 0.0
# lessons_(4,_1,_'Art') 0.0
# lessons_(4,_2,_'Math') 0.0
# lessons_(4,_2,_'Science') 0.0
# lessons_(4,_2,_'Hebrew') 0.0
# lessons_(4,_2,_'Bible') 0.0
# lessons_(4,_2,_'Music') 0.0
# lessons_(4,_2,_'Education') 0.0
# lessons_(4,_2,_'Sport') 0.0
# lessons_(4,_2,_'Art') 0.0
# lessons_(4,_3,_'Math') 0.0
# lessons_(4,_3,_'Science') 0.0
# lessons_(4,_3,_'Hebrew') 0.0
# lessons_(4,_3,_'Bible') 0.0
# lessons_(4,_3,_'Music') 0.0
# lessons_(4,_3,_'Education') 0.0
# lessons_(4,_3,_'Sport') 0.0
# lessons_(4,_3,_'Art') 0.0
# lessons_(4,_4,_'Math') 0.0
# lessons_(4,_4,_'Science') 0.0
# lessons_(4,_4,_'Hebrew') 0.0
# lessons_(4,_4,_'Bible') 0.0
# lessons_(4,_4,_'Music') 0.0
# lessons_(4,_4,_'Education') 0.0
# lessons_(4,_4,_'Sport') 0.0
# lessons_(4,_4,_'Art') 0.0
# lessons_(4,_5,_'Math') 0.0
# lessons_(4,_5,_'Science') 0.0
# lessons_(4,_5,_'Hebrew') 0.0
# lessons_(4,_5,_'Bible') 0.0
# lessons_(4,_5,_'Music') 1.0
# lessons_(4,_5,_'Education') 0.0
# lessons_(4,_5,_'Sport') 0.0
# lessons_(4,_5,_'Art') 0.0
# lessons_(4,_6,_'Math') 0.0
# lessons_(4,_6,_'Science') 0.0
# lessons_(4,_6,_'Hebrew') 0.0
# lessons_(4,_6,_'Bible') 0.0
# lessons_(4,_6,_'Music') 0.0
# lessons_(4,_6,_'Education') 0.0
# lessons_(4,_6,_'Sport') 0.0
# lessons_(4,_6,_'Art') 0.0
# lessons_(4,_7,_'Math') 0.0
# lessons_(4,_7,_'Science') 0.0
# lessons_(4,_7,_'Hebrew') 0.0
# lessons_(4,_7,_'Bible') 0.0
# lessons_(4,_7,_'Music') 0.0
# lessons_(4,_7,_'Education') 0.0
# lessons_(4,_7,_'Sport') 0.0
# lessons_(4,_7,_'Art') 0.0
# lessons_(4,_8,_'Math') 0.0
# lessons_(4,_8,_'Science') 0.0
# lessons_(4,_8,_'Hebrew') 0.0
# lessons_(4,_8,_'Bible') 0.0
# lessons_(4,_8,_'Music') 1.0
# lessons_(4,_8,_'Education') 0.0
# lessons_(4,_8,_'Sport') 0.0
# lessons_(4,_8,_'Art') 0.0
# lessons_(5,_1,_'Math') 0.0
# lessons_(5,_1,_'Science') 0.0
# lessons_(5,_1,_'Hebrew') 0.0
# lessons_(5,_1,_'Bible') 1.0
# lessons_(5,_1,_'Music') 0.0
# lessons_(5,_1,_'Education') 0.0
# lessons_(5,_1,_'Sport') 0.0
# lessons_(5,_1,_'Art') 0.0
# lessons_(5,_2,_'Math') 0.0
# lessons_(5,_2,_'Science') 0.0
# lessons_(5,_2,_'Hebrew') 0.0
# lessons_(5,_2,_'Bible') 0.0
# lessons_(5,_2,_'Music') 0.0
# lessons_(5,_2,_'Education') 0.0
# lessons_(5,_2,_'Sport') 0.0
# lessons_(5,_2,_'Art') 0.0
# lessons_(5,_3,_'Math') 0.0
# lessons_(5,_3,_'Science') 0.0
# lessons_(5,_3,_'Hebrew') 0.0
# lessons_(5,_3,_'Bible') 0.0
# lessons_(5,_3,_'Music') 0.0
# lessons_(5,_3,_'Education') 0.0
# lessons_(5,_3,_'Sport') 0.0
# lessons_(5,_3,_'Art') 0.0
# lessons_(5,_4,_'Math') 0.0
# lessons_(5,_4,_'Science') 0.0
# lessons_(5,_4,_'Hebrew') 0.0
# lessons_(5,_4,_'Bible') 0.0
# lessons_(5,_4,_'Music') 0.0
# lessons_(5,_4,_'Education') 0.0
# lessons_(5,_4,_'Sport') 0.0
# lessons_(5,_4,_'Art') 0.0
# lessons_(5,_5,_'Math') 0.0
# lessons_(5,_5,_'Science') 0.0
# lessons_(5,_5,_'Hebrew') 0.0
# lessons_(5,_5,_'Bible') 0.0
# lessons_(5,_5,_'Music') 0.0
# lessons_(5,_5,_'Education') 0.0
# lessons_(5,_5,_'Sport') 0.0
# lessons_(5,_5,_'Art') 0.0
# lessons_(5,_6,_'Math') 0.0
# lessons_(5,_6,_'Science') 0.0
# lessons_(5,_6,_'Hebrew') 0.0
# lessons_(5,_6,_'Bible') 0.0
# lessons_(5,_6,_'Music') 0.0
# lessons_(5,_6,_'Education') 0.0
# lessons_(5,_6,_'Sport') 0.0
# lessons_(5,_6,_'Art') 0.0
# lessons_(5,_7,_'Math') 0.0
# lessons_(5,_7,_'Science') 0.0
# lessons_(5,_7,_'Hebrew') 0.0
# lessons_(5,_7,_'Bible') 1.0
# lessons_(5,_7,_'Music') 0.0
# lessons_(5,_7,_'Education') 0.0
# lessons_(5,_7,_'Sport') 0.0
# lessons_(5,_7,_'Art') 0.0
# lessons_(5,_8,_'Math') 0.0
# lessons_(5,_8,_'Science') 0.0
# lessons_(5,_8,_'Hebrew') 0.0
# lessons_(5,_8,_'Bible') 0.0
# lessons_(5,_8,_'Music') 0.0
# lessons_(5,_8,_'Education') 0.0
# lessons_(5,_8,_'Sport') 0.0
# lessons_(5,_8,_'Art') 0.0
# lessons_(6,_1,_'Math') 0.0
# lessons_(6,_1,_'Science') 0.0
# lessons_(6,_1,_'Hebrew') 0.0
# lessons_(6,_1,_'Bible') 0.0
# lessons_(6,_1,_'Music') 0.0
# lessons_(6,_1,_'Education') 0.0
# lessons_(6,_1,_'Sport') 0.0
# lessons_(6,_1,_'Art') 0.0
# lessons_(6,_2,_'Math') 0.0
# lessons_(6,_2,_'Science') 0.0
# lessons_(6,_2,_'Hebrew') 0.0
# lessons_(6,_2,_'Bible') 0.0
# lessons_(6,_2,_'Music') 0.0
# lessons_(6,_2,_'Education') 0.0
# lessons_(6,_2,_'Sport') 0.0
# lessons_(6,_2,_'Art') 0.0
# lessons_(6,_3,_'Math') 0.0
# lessons_(6,_3,_'Science') 0.0
# lessons_(6,_3,_'Hebrew') 0.0
# lessons_(6,_3,_'Bible') 0.0
# lessons_(6,_3,_'Music') 0.0
# lessons_(6,_3,_'Education') 1.0
# lessons_(6,_3,_'Sport') 0.0
# lessons_(6,_3,_'Art') 0.0
# lessons_(6,_4,_'Math') 0.0
# lessons_(6,_4,_'Science') 0.0
# lessons_(6,_4,_'Hebrew') 0.0
# lessons_(6,_4,_'Bible') 0.0
# lessons_(6,_4,_'Music') 0.0
# lessons_(6,_4,_'Education') 0.0
# lessons_(6,_4,_'Sport') 0.0
# lessons_(6,_4,_'Art') 0.0
# lessons_(6,_5,_'Math') 0.0
# lessons_(6,_5,_'Science') 0.0
# lessons_(6,_5,_'Hebrew') 0.0
# lessons_(6,_5,_'Bible') 0.0
# lessons_(6,_5,_'Music') 0.0
# lessons_(6,_5,_'Education') 0.0
# lessons_(6,_5,_'Sport') 0.0
# lessons_(6,_5,_'Art') 0.0
# lessons_(6,_6,_'Math') 0.0
# lessons_(6,_6,_'Science') 0.0
# lessons_(6,_6,_'Hebrew') 0.0
# lessons_(6,_6,_'Bible') 0.0
# lessons_(6,_6,_'Music') 0.0
# lessons_(6,_6,_'Education') 0.0
# lessons_(6,_6,_'Sport') 0.0
# lessons_(6,_6,_'Art') 0.0
# lessons_(6,_7,_'Math') 0.0
# lessons_(6,_7,_'Science') 0.0
# lessons_(6,_7,_'Hebrew') 0.0
# lessons_(6,_7,_'Bible') 0.0
# lessons_(6,_7,_'Music') 0.0
# lessons_(6,_7,_'Education') 0.0
# lessons_(6,_7,_'Sport') 0.0
# lessons_(6,_7,_'Art') 0.0
# lessons_(6,_8,_'Math') 0.0
# lessons_(6,_8,_'Science') 0.0
# lessons_(6,_8,_'Hebrew') 0.0
# lessons_(6,_8,_'Bible') 0.0
# lessons_(6,_8,_'Music') 0.0
# lessons_(6,_8,_'Education') 1.0
# lessons_(6,_8,_'Sport') 0.0
# lessons_(6,_8,_'Art') 0.0

# %%
output = []
for month, factory in production:
    var_output = {
        'Month': month,
        'Factory': factory,
        'Production': production[(month, factory)].varValue,
        'Factory Status': factory_status[(month, factory)].varValue
    }
    output.append(var_output)
output_df = pd.DataFrame.from_records(output).sort_values(['Month', 'Factory'])
output_df.set_index(['Month', 'Factory'], inplace=True)
output_df
# Out:
#                Factory Status  Production
# Month Factory
# 1     A                   1.0     70000.0
#       B                   1.0     50000.0
# 2     A                   1.0     45000.0
#       B                   1.0     55000.0
# 3     A                   1.0     70000.0
#       B                   1.0     60000.0
# 4     A                   1.0     30000.0
#       B                   1.0    100000.0
# 5     A                   1.0    140000.0
#       B                   0.0         0.0
# 6     A                   1.0     60000.0
#       B                   1.0     70000.0
# 7     A                   1.0     90000.0
#       B                   1.0     60000.0
# 8     A                   1.0     70000.0
#       B                   1.0    100000.0
# 9     A                   1.0    100000.0
#       B                   1.0    100000.0
# 10    A                   1.0    190000.0
#       B                   0.0         0.0
# 11    A                   1.0     80000.0
#       B                   1.0     60000.0
# 12    A                   1.0    100000.0
#       B                   0.0         0.0

# %% [markdown]
# Notice above that the factory status is 0 when not producing and 1 when it is producing

# %%
# Print our objective function value (Total Costs)
print (pulp.value(model.objective))
# Out:
# 0.0
